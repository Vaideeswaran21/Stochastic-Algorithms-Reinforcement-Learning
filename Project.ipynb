# %% [markdown]
# # **Import the Necessary Libraries**

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
from stable_baselines3 import PPO, DQN, A2C, TD3, DDPG, SAC

# %% [markdown]
# # **Generation of the City Layout**

# %%
"""

Arguments: Number of rows and columns in the layout and the coordinates of an entity (possibly the Drone or the Target)
Functionality: We do not want the entity to lie on the peripheral wall of the layout (read the warning below).
               In other words, the x-coordinate of the entity must not match the zeroth or the last row. Likewise, for the
               y-coordinate.
Return: True (if the coordinates do not correspond to a peripheral wall location), else False

"""

def check_location(rows, columns, coordinates):
    
    x_coordinate, y_coordinate = coordinates[0], coordinates[1]

    if x_coordinate <= 0 or x_coordinate >= rows - 1:
        return False
    if y_coordinate <= 0 or y_coordinate >= columns - 1:
        return False

    return True

###############################################################################################################################

"""

Arguments: The dimensions of the layout (tuple of the form (rows, columns)), locations of the target and drone (tuple of
           the form (x coordinate, y coordinate)), and obstacle density (fraction of the total number of grid points covered
           by obstacles) [default: 0.2]
Functionality: Generation of a random city layout with the given dimensions and obstacle density. Note that the actual
               layout will be present in a square with dimensions (rows - 2 * columns - 2) as a perimeter wall will be
               present. 'D' and 'T' denote the location of the drone and target location respectively.
               Obstacles are denoted by '#'. The drone can use white spaces present in the returned grid for
               navigation.
Return: A randomly generated grid (not necessarily solvable!)
Warning: The location of the Drone and Target must not be on the periphery and must not coincide with each other! 
         Please provide the locations assuming zero-based indexing.
References:
            1. np.random.random_sample: https://numpy.org/doc/2.0/reference/random/generated/numpy.random.random_sample.html#numpy.random.random_sample
            2. np.where: https://numpy.org/doc/stable/reference/generated/numpy.where.html
            3. np.reshape: https://numpy.org/doc/stable/reference/generated/numpy.reshape.html
            4. ValueError: https://docs.python.org/3/tutorial/errors.html

"""

def generate_layout(dimensions, location_drone, location_target, obstacle_density = 0.2):
    
    rows, columns = dimensions[0], dimensions[1] # Extract the number of rows and columns given the dimensions
    layout = np.ones((rows, columns)) # Initiliaze the layout with all 1's (automatically takes care of the perimeter wall)

    # The grid is discrete! Therefore, the location of the Drone and Target are being converted to integral values by default.
    
    location_drone = (int(location_drone[0]), int(location_drone[1]))
    location_target = (int(location_target[0]), int(location_target[1]))

    ###########################################################################################################################

    # Check the Validity of the location of the drone and target

    if not check_location(rows, columns, location_drone):
        raise ValueError("Coordinates of the Drone are invalid! Read the Warning!")

    if not check_location(rows, columns, location_target):
        raise ValueError("Coordinates of the Target are invalid! Read the Warning!")

    if location_drone == location_target:
        raise ValueError("Location of both the drone and target are coinciding! Read the Warning")
    
    ###########################################################################################################################

    # Here, we denote the obstacles by 1 and the open space by 0. Conversion to string will be done later
    # Obtain (rows - 2) * (columns - 2) random values uniformly distributed between 0 and 1. If the random value is above
    # the obstacle density, set the grid point to 0, else 1. 
    
    layout_array = np.random.random_sample(size = (rows - 2) * (columns - 2))
    layout_array = np.where(layout_array < obstacle_density, 1, 0)

    ###########################################################################################################################

    layout_array = np.reshape(layout_array, ((rows - 2, columns - 2))) # Reshape to a (rows - 2) * (columns - 2) matrix
    layout[1 : rows - 1, 1 : columns - 1] = layout_array # This sub-matrix characterizes the city layout. Fill in the layout!

    ###########################################################################################################################

    string_format_layout = np.where(layout == 1, "#", " ") # If 1 is present => Obstacle, replace with '#'
    string_format_layout[location_drone[0], location_drone[1]] = 'D' # Set the specified drone location
    string_format_layout[location_target[0], location_target[1]] = 'T' # Set the specified target location

    ###########################################################################################################################
    
    return string_format_layout

###############################################################################################################################

# Test the Code here

drone_location = (1, 1) # Example drone location
target_location = (8, 8) # Example target location
layout_size = (10, 10) # Example layout size
print(generate_layout(layout_size, drone_location, target_location)) # For visualization of the layout
# Out:
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]

# %% [markdown]
# # **Is the Random Layout Solvable?**
# ### **Apply DFS!**
#
# #### Since DFS implementation is not the focus of this work, we use the algorithm from the DSA Lectures taught by Professor Madhavan Mukund, whom we duly acknowledge.
# #### Reference: https://www.youtube.com/playlist?list=PLZ2ps__7DhBaDccbZRgiU1sHX2gZrQ-XT

# %% [markdown]
# ## **Setup the Adjacency List**

# %%
"""

Arguments: prospective layout, raster index for each state/ coordinate presented as a dictionary
Functionality: Using the function, we find the adjacency list. It is a dictionary where the keys represent the state indices
               , and values represent the neighboring indices. Keys and values must correspond to only non-obstacle states.
Return: Adjacency list

"""

def generate_adjacency_list(prospective, raster_index_dict):

    AList = {} # Initialize the adjacency list with an empty dictionary
    
    # We know that the peripheral wall is entirely comprised of only '#'. Therefore, the iterations start from 1 till rows - 1 (or)
    # columns - 1 accordingly
    
    for i in range(1, layout_size[0] - 1):
        for j in range(1, layout_size[1] - 1):
            if prospective[i][j] != '#': # Key should not be an obstacle
                AList[raster_index_dict[(i, j)]] = [] # If the key is not an obstacle, we are interested in the neighbors
                
                # Neighbor should not be an obstacle. If it is an obstacle, it prevents motion in that direction.
                # There are 4 possible neighbors.
                
                if prospective[i - 1][j] != '#':
                    AList[raster_index_dict[(i, j)]].append(raster_index_dict[(i - 1, j)])
    
                if prospective[i][j - 1] != '#':
                    AList[raster_index_dict[(i, j)]].append(raster_index_dict[(i, j - 1)])
    
                if prospective[i + 1][j] != '#':
                    AList[raster_index_dict[(i, j)]].append(raster_index_dict[(i + 1, j)])
    
                if prospective[i][j + 1] != '#':
                    AList[raster_index_dict[(i, j)]].append(raster_index_dict[(i, j + 1)])

    return AList

# %% [markdown]
# ## **Implement DFS**

# %%
"""

Arguments: Adjacency list, two empty dictionaries named visited and parent that store information accordingly
Functionality: Initially, the DFS algorithm has yet to visit any states. Therefore, set visited as False. We are also not
               yet aware of how to visit a state from the starting state (Initial drone location). Therefore, set the parent
               as -1 for all the states. Raster scanning assigns indices starting from 0, implying that no state can have 
               a parent as -1. We safely conclude that our initialization does not result in any future conflict.
Return: The initialized form of dictionaries visited, and the parent

"""

def DFSInitList(AList, visited, parent):
    for i in AList.keys():
        visited[i] = False
        parent[i] = -1
    return visited, parent

###############################################################################################################################

"""

Arguments: Adjacency list and dictionaries visited, and parent
Functionality: Implementation of the DFS Algorithm in a recursive fashion
Return: None

"""

def DFSList(AList, v, visited, parent):
    visited[v] = True

    for k in AList[v]:
        if (not visited[k]):
            parent[k] = v
            DFSList(AList, k, visited, parent)

    return

# %% [markdown]
# ## **Test the code here**

# %%
drone_location = (1, 1) # Example drone location
target_location = (8, 8) # Example target location
layout_size = (10, 10) # Example layout size
prospective = generate_layout(layout_size, drone_location, target_location, obstacle_density = 0.3) # Generate a prospective layout

###############################################################################################################################

"""

Argument: layout
Functionality: The below function provides the raster indexation corresponding to each state in the layout
Return: A dictionary where the coordinate (x, y) is the key and the raster index is the value

"""

def raster_scan(layout):
    raster_index_dict = {} # Initialize the dictionary
    counter = 0 # Enables raster scan indexation
    rows, columns = np.shape(layout)

    # Perform the raster scan

    for i in range(rows):
        for j in range(columns):
            raster_index_dict[(i, j)] = counter
            counter = counter + 1

    return raster_index_dict

###############################################################################################################################

raster_dict = raster_scan(prospective) # Obtain the dictionary with the raster indexation
AList = generate_adjacency_list(prospective, raster_dict) # Generate the adjacency list
(visited, parent) = ({}, {}) # Set visit and parent as empty dictionaries

visited, parent = DFSInitList(AList, visited, parent) # Populate these dictionaries given the adjacency list
DFSList(AList, raster_dict[drone_location], visited, parent) # Implement DFS recursively

###############################################################################################################################

print("Prospective Layout")
print(prospective)
print("States visitable by the DFS Algorithm")

visitable_states = prospective.copy() # Prevent the overwriting of the original matrix

for i in range(layout_size[0]):
    for j in range(layout_size[1]):
        if prospective[i, j] != 'D' and prospective[i, j] != 'T' and prospective[i, j] != '#':

            # Check if any state is visitable, given that it is not the start, end, or obstacle
            
            if visited[raster_dict[(i, j)]]:
                visitable_states[i, j] = 'v'

print(visitable_states)
###############################################################################################################################

if not visited[raster_dict[target_location]]:
    print("The prospective layout is not solvable")
else:
    print("The prospective layout is solvable")
# Out:
# Prospective Layout
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' ' ' ' ' '#' '#' '#']
#  ['#' ' ' '#' ' ' '#' '#' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' '#' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# States visitable by the DFS Algorithm
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' 'v' '#' '#' 'v' 'v' 'v' 'v' '#']
#  ['#' 'v' 'v' '#' '#' 'v' 'v' '#' '#' '#']
#  ['#' 'v' '#' 'v' '#' '#' 'v' 'v' '#' '#']
#  ['#' 'v' 'v' 'v' 'v' 'v' '#' 'v' 'v' '#']
#  ['#' 'v' 'v' 'v' '#' 'v' 'v' 'v' '#' '#']
#  ['#' 'v' 'v' '#' 'v' 'v' 'v' '#' 'v' '#']
#  ['#' 'v' 'v' 'v' 'v' '#' '#' '#' 'v' '#']
#  ['#' 'v' 'v' 'v' 'v' 'v' 'v' 'v' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# The prospective layout is solvable

# %% [markdown]
# ## **Return ONLY Solvable Layouts**

# %%
"""

Arguments: size of the layout, locations of the drone and the target, obstacle density, and the maximum number of iterations
           [def: 100 iterations]
Functionality: This function will consider, at most, the max_iter number of randomly generated layouts. If any prospective
               layout is solvable (checked using DFS), we return it after indicating the number of iterations it
               took to create that layout. If the obstacle density is high, hitting a candidate might not be possible.
Return: solvable layout or False (if no prospective layout was found)

"""


def strictly_solvable(layout_size, drone_location, target_location, obstacle_density = 0.2, max_iter = 100, verbose = True):
    
    for x in range(max_iter):
        prospective = generate_layout(layout_size, drone_location, target_location, obstacle_density) # Generate a 
                                                                                                      # prospective layout

        ######################################################################################################################

        raster_dict = raster_scan(prospective) # Obtain the dictionary with the raster indexation

        ######################################################################################################################

        AList = generate_adjacency_list(prospective, raster_dict) # Generate the adjacency list

        (visited, parent) = ({}, {}) # Set visit and parent as empty dictionaries
        visited, parent = DFSInitList(AList, visited, parent) # Populate these dictionaries given the adjacency list
        DFSList(AList, raster_dict[drone_location], visited, parent) # Implement DFS recursively

        ######################################################################################################################

        if visited[raster_dict[target_location]]: # If the layout is solvable
            if verbose:
                print("Iterations take: ", x)
                print(prospective)
            return prospective
    
    print("The obstacle density is very high! Consider reducing it")
    return False

###############################################################################################################################

# Test the code here

drone_location = (1, 1) # Example drone location
target_location = (5, 5) # Example target location
layout_size = (7, 7) # Example layout size
layout = strictly_solvable(layout_size, drone_location, target_location, obstacle_density = 0.5, verbose = True) # Generate a solvable layout
# Out:
# Iterations take:  6
# [['#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' '#' '#' ' ' '#' '#']
#  ['#' ' ' '#' ' ' ' ' '#' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#']]

# %% [markdown]
# # **Generating All the Test Cases**
#
# There are 20 simulation scenarios that are considered.
# - The layout sizes are varied from 5 x 5 to 8 x 8 in steps of 1.
#
# - The obstacle densities are varied from 0 to 0.4 in steps of 0.1.
#
# Each simulation scenario admits 50 test cases + 1 test case for learning.

# %%
density = [0, 0.1, 0.2, 0.3, 0.4] # Density of obstacles
size = [5, 6, 7, 8] # Size of the layout
n_test_cases = 51 # Number of test cases
drone_location = (1, 1) # Example drone location
test_cases = [] # Store the test cases

for s in size:
    target_location = (s - 2, s - 2) # Example target location
    layout_size = (s, s) # Example layout size
    for d in density:
        temp = []
        for k in range(n_test_cases):
            layout = strictly_solvable(layout_size, drone_location, target_location, obstacle_density = d, verbose = False) # Generate a solvable layout
            temp.append(layout) # Append the layout to the list of test cases
        test_cases.append(temp) # Append the list of test cases to the main list

# %% [markdown]
# # <center>  **RL Simulations** </center>
# ### All the simulations were done using the [Gym framework](https://www.gymlibrary.dev/content/environment_creation)
#
# ### We use the following environment naming convention:
#
# ---
#
# ### MDP Characterization:
#
# 1. **Discrete:** *Disc*
# 2. **Continuous:** *Cont*
#
# ---
#
# ### Reward Characterization:
#
# 1. **Deterministic:** *Det*
# 2. **Probabilistic:** *Prob*
#
# ---
#
# ### Example:
#
# For a **Discrete MDP** with a **Deterministic Reward Mechanism**, we use the naming: **DiscDetEnv**

# %% [markdown]
# ## **Case 1: Discrete Markov Decision Process with Deterministic Reward**

# %% [markdown]
# ### **Locally Optimal Action**

# %% [markdown]
# #### **Environment Definition**

# %%
class DiscDetEnv(gym.Env):
    
    def __init__(self, layout, drone_location, target_location, completion_reward = 100000, obstacle_hit_reward = -100000,
                         reduce_dist_reward = 10, increase_dist_reward = -5):

        self.layout = layout.copy() # Layout is made an attribute of the object so that it can be used in the methods
        self.rows, self.columns = np.shape(layout) # Obtain the number of rows and columns
        self.raster_dict = raster_scan(layout) # Obtain the dictionary with the raster indexation
        self.start = drone_location # Starting position of the drone
        self.target_location = target_location # Target/ Delivery location
        self.agent_location = self.start

        #######################################################################################################################
        
        # Rewards

        self.completion_reward = completion_reward
        self.obstacle_hit_reward = obstacle_hit_reward
        self.reduce_dist_reward = reduce_dist_reward
        self.increase_dist_reward = increase_dist_reward
        self.reduce_dist_reward = reduce_dist_reward

        #######################################################################################################################

        # Observations are dictionaries with the agent's and the target's location.

        """

        The -2 helps to characterize the true number of states. We want to exclude the possibility of both the target and
        agent (drone) from being present on the peripheral walls.
        Number of valid states <= (rows - 2) * (columns - 2)
        We prevent the drone from running over obstacles with the reward mechanism.
        
        """
        
        self.observation_space = spaces.Dict(
            {
                "agent": spaces.MultiDiscrete([self.rows, self.columns])
            }
        )

        #######################################################################################################################

        self.action_space = spaces.Discrete(4) # We have 4 actions, corresponding to "right", "up", "left", "down"

        """
        
        The following dictionary maps abstract actions from `self.action_space` to 
        the direction we will walk in if that action is taken.
        I.e., 0 corresponds to "right," 1 to "up," etc.
        
        """
        
        self.action_to_direction = {
            0: np.array([1, 0]),
            1: np.array([0, 1]),
            2: np.array([-1, 0]),
            3: np.array([0, -1]),
        }

    ###########################################################################################################################
    
    def reset(self):
        self.agent_location = self.start
        return {'agent': self.agent_location}

    ###########################################################################################################################

    def reward_mechanism(self, action):
            
            agent_coordinates = np.array([self.agent_location[0], self.agent_location[1]])
            target_coordinates = np.array([self.target_location[0], self.target_location[1]])

            ##################################################################################################################
            
            if action == 0:
                prospective_coordinates = [self.agent_location[0] + 1, self.agent_location[1]]
                if self.layout[self.agent_location[0] + 1][self.agent_location[1]] == '#':
                    return self.obstacle_hit_reward
                
                if self.layout[self.agent_location[0] + 1][self.agent_location[1]] == 'T':
                    return self.completion_reward
                
                else:
                    if np.linalg.norm(agent_coordinates - target_coordinates, ord = 1) < np.linalg.norm(prospective_coordinates - target_coordinates, ord = 1):
                        return self.increase_dist_reward
                    if np.linalg.norm(agent_coordinates - target_coordinates, ord = 1) > np.linalg.norm(prospective_coordinates - target_coordinates, ord = 1):
                        return self.reduce_dist_reward

            ##################################################################################################################

            if action == 1:
                prospective_coordinates = [self.agent_location[0], self.agent_location[1] + 1]
                if self.layout[self.agent_location[0]][self.agent_location[1] + 1] == '#':
                    return self.obstacle_hit_reward
                
                if self.layout[self.agent_location[0]][self.agent_location[1] + 1] == 'T':
                    return self.completion_reward

                else:
                    if np.linalg.norm(agent_coordinates - target_coordinates, ord = 1) < np.linalg.norm(prospective_coordinates - target_coordinates, ord = 1):
                        return self.increase_dist_reward
                    if np.linalg.norm(agent_coordinates - target_coordinates, ord = 1) > np.linalg.norm(prospective_coordinates - target_coordinates, ord = 1):
                        return self.reduce_dist_reward

            ##################################################################################################################

            if action == 2:
                prospective_coordinates = [self.agent_location[0] - 1, self.agent_location[1]]
                if self.layout[self.agent_location[0] - 1][self.agent_location[1]] == '#':
                    return self.obstacle_hit_reward
                
                if self.layout[self.agent_location[0] - 1][self.agent_location[1]] == 'T':
                    return self.completion_reward

                else:
                    if np.linalg.norm(agent_coordinates - target_coordinates, ord = 1) < np.linalg.norm(prospective_coordinates - target_coordinates, ord = 1):
                        return self.increase_dist_reward
                    if np.linalg.norm(agent_coordinates - target_coordinates, ord = 1) > np.linalg.norm(prospective_coordinates - target_coordinates, ord = 1):
                        return self.reduce_dist_reward

            ##################################################################################################################

            if action == 3:
                prospective_coordinates = [self.agent_location[0], self.agent_location[1] - 1]
                if self.layout[self.agent_location[0]][self.agent_location[1] - 1] == '#':
                    return self.obstacle_hit_reward
                
                if self.layout[self.agent_location[0]][self.agent_location[1] - 1] == 'T':
                    return self.completion_reward

                else:
                    if np.linalg.norm(agent_coordinates - target_coordinates, ord = 1) < np.linalg.norm(prospective_coordinates - target_coordinates, ord = 1):
                        return self.increase_dist_reward
                    if np.linalg.norm(agent_coordinates - target_coordinates, ord = 1) > np.linalg.norm(prospective_coordinates - target_coordinates, ord = 1):
                        return self.reduce_dist_reward

    ###########################################################################################################################
            
    def step(self):
        rewards_dict = {
                            0: self.reward_mechanism(0),
                            1: self.reward_mechanism(1),
                            2: self.reward_mechanism(2),
                            3: self.reward_mechanism(3)
                        }
        
        # Check if all the values are distinct. If they are, we can directly obtain the action with the maximum reward

        if len(rewards_dict.values()) == len(set(rewards_dict.values())):

            action = max(rewards_dict, key = rewards_dict.get)

        # If the values are not distinct, we need to break the tie. We will randomly select one of the actions with the maximum reward
        
        else:
            action = np.random.choice([key for key in rewards_dict.keys() if rewards_dict[key] == max(rewards_dict.values())])

        reward = rewards_dict[action]
        direction = self.action_to_direction[action] # Map the action to the walking direction
        self.layout[self.agent_location[0], self.agent_location[1]] = ' ' # The agent has left the current location

        self.agent_location = (self.agent_location[0] + direction[0], self.agent_location[1] + direction[1]) # Update the agent's location
        self.layout[self.agent_location[0], self.agent_location[1]] = 'D' # The agent has reached the new location
        
        # An episode is done iff the agent has reached the target
        if self.agent_location == self.target_location:
            terminated = True
        else:
            terminated = False


        return reward, terminated, action

    ###########################################################################################################################

    def render(self):
        present_layout = self.layout.copy()
        present_layout[self.start[0], self.start[1]] = ' '
        present_layout[self.agent_location[0], self.agent_location[1]] = 'D'
        print(present_layout)
        return

# %% [markdown]
# #### **Test Case: Where the Policy Works**

# %%
print("Initial Setup")
layout_size = (10, 10)
drone_location = (1, 1)
target_location = (8, 8)
layout = strictly_solvable(layout_size, drone_location, target_location, obstacle_density = 0.2) # Generate a solvable layout
layout_RL_Learning = layout.copy()

env = DiscDetEnv(layout, (1, 1), (8, 8))
state = env.reset()
terminated = False
counter = 0

while not terminated:
    reward, terminated, action = env.step()
    state = env.agent_location
    print(f"Action: {action}, New State: {state}, Reward: {reward}, Terminated: {terminated}")
    env.render()
    counter = counter + 1
    
print("Number of steps taken: ", counter)
# Out:
# Initial Setup
# Iterations take:  0
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' '#' ' ' '#' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' '#' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (1, 2), Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' '#' ' ' '#' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' '#' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (2, 2), Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' 'D' ' ' '#' ' ' '#' ' ' '#' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' '#' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (2, 3), Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' 'D' '#' ' ' '#' ' ' '#' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' '#' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (3, 3), Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' '#' ' ' '#' '#']
#  ['#' '#' '#' 'D' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' '#' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (3, 4), Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' '#' ' ' '#' '#']
#  ['#' '#' '#' ' ' 'D' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' '#' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (3, 5), Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' '#' ' ' '#' '#']
#  ['#' '#' '#' ' ' ' ' 'D' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' '#' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (4, 5), Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' '#' ' ' '#' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' '#' '#' 'D' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' '#' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (4, 6), Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' '#' ' ' '#' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' '#' '#' ' ' 'D' ' ' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' '#' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (5, 6), Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' '#' ' ' '#' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' 'D' ' ' ' ' '#']
#  ['#' '#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' '#' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (5, 7), Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' '#' ' ' '#' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' 'D' ' ' '#']
#  ['#' '#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' '#' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (5, 8), Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' '#' ' ' '#' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' 'D' '#']
#  ['#' '#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' '#' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (6, 8), Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' '#' ' ' '#' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' '#' ' ' ' ' ' ' 'D' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' '#' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (7, 8), Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' '#' ' ' '#' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#' 'D' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' '#' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 8), Reward: 100000, Terminated: True
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' '#' ' ' '#' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' '#' ' ' 'D' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Number of steps taken:  14

# %% [markdown]
# #### **Test Case: Where the Policy Fails**

# %%
print("Initial Setup")
layout = strictly_solvable(layout_size, drone_location, target_location, obstacle_density = 0.5) # Generate a solvable layout
layout_RL_Learning = layout.copy()

env = DiscDetEnv(layout, (1, 1), (8, 8))
state = env.reset()
terminated = False
counter = 0

while not terminated:
    reward, terminated, action = env.step()
    state = env.agent_location
    print(f"Action: {action}, New State: {state}, Reward: {reward}, Terminated: {terminated}")
    env.render()
    counter = counter + 1

    if counter > 100:
        break
    
print("Number of steps taken: ", counter)
# Out:
# Initial Setup
# Iterations take:  6
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (2, 1), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (3, 1), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' 'D' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (4, 1), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (5, 1), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' 'D' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (6, 1), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (6, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (7, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: (8, 1), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: (8, 1), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: (8, 1), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: (8, 1), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: (8, 1), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: (8, 1), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: (8, 1), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: (8, 1), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: (8, 1), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: (8, 1), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: (8, 1), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: (8, 1), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: (8, 1), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: (8, 1), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: (8, 1), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: (8, 1), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: (8, 1), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: (8, 1), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: (7, 2), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' 'D' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: (8, 2), Reward: 1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: (8, 1), Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' '#' '#' '#' '#']
#  ['#' ' ' '#' '#' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#' '#']
#  ['#' ' ' '#' '#' '#' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' '#' '#' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' '#' ' ' '#' '#' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Number of steps taken:  101

# %% [markdown]
# ### **Policy using RL Algorithms**
#
# We re-define the environment to make it compatible with the library Stable Baselines3 which offers a high-level interface to train and evaluate RL agents.

# %% [markdown]
# #### **Compatible Environment Definition**

# %%
class DiscDetCompatEnv(gym.Env):
    def __init__(self, layout, drone_location, target_location, completion_reward = 100000, obstacle_hit_reward = -100000,
                 reduce_dist_reward = 10, increase_dist_reward = -5):
        super(DiscDetCompatEnv, self).__init__()  # Ensure compatibility by calling the parent constructor

        self.layout = layout # Layout is made an attribute of the object so that it can be used in the methods
        self.layout_duplicate = layout.copy() # Duplicate layout to prevent overwriting
        self.rows, self.columns = np.shape(layout) # Obtain the number of rows and columns
        self.raster_dict = raster_scan(layout) # Obtain the dictionary with the raster indexation
        self.start = drone_location # Starting position of the drone
        self.target_location = target_location # Target/ Delivery location
        self.agent_location = self.start # Initialize the agent location
        # self.step_count = 0 # Initialize the step count (optional)

        #######################################################################################################################
        
        # Rewards

        self.completion_reward = completion_reward
        self.obstacle_hit_reward = obstacle_hit_reward
        self.reduce_dist_reward = reduce_dist_reward
        self.increase_dist_reward = increase_dist_reward
        self.reduce_dist_reward = reduce_dist_reward

        #######################################################################################################################

        # Observations are dictionaries with the agent's location. Note that the target's location is fixed.

        """
        
        We prevent the drone from running over obstacles with the reward mechanism.
        
        """
        
        self.observation_space = spaces.Dict(
            {
                "agent": spaces.MultiDiscrete([self.rows, self.columns])
            }
        )

        #######################################################################################################################

        self.action_space = spaces.Discrete(4) # We have 4 actions, corresponding to "right", "up", "left", "down"

        """
        
        The following dictionary maps abstract actions from `self.action_space` to 
        the direction we will walk in if that action is taken.
        I.e., 0 corresponds to "right," 1 to "up," etc.
        
        """
        
        self.action_to_direction = {
            0: np.array([1, 0]),
            1: np.array([0, 1]),
            2: np.array([-1, 0]),
            3: np.array([0, -1]),
        }

    ###########################################################################################################################    

    def reset(self, seed = None, **kwargs):
    
        super().reset(seed = seed) # Set the seed for reproducibility
        if seed is not None:
            np.random.seed(seed)

        self.agent_location = self.start # Reset agent location
        self.layout = self.layout_duplicate.copy() # Reset the layout

        # Return the observation and an empty dictionary as additional info (as required by Gym)
        return {'agent': np.array(self.agent_location)}, {}
    
    ###########################################################################################################################

    def step(self, action):
        action = int(action)  # Ensure action is an integer
        reward = self.reward_mechanism(action)
        if reward == self.obstacle_hit_reward:
            terminated = False
            truncated = False
            observation = {'agent': np.array(self.agent_location)}
            info = {}  # Add any relevant information here (e.g., additional metrics)
            return observation, reward, terminated, truncated, info
        
        direction = self.action_to_direction[action]  # Map the action to the walking direction

        # layout_copy = self.layout.copy()
        self.layout[self.agent_location[0], self.agent_location[1]] = ' '  # Clear current location
        self.agent_location =   (
                                    np.clip(self.agent_location[0] + direction[0], 1, self.rows - 2), 
                                    np.clip(self.agent_location[1] + direction[1], 1, self.columns - 2)
                                )  # Update the agent location
        self.layout[self.agent_location[0], self.agent_location[1]] = 'D'  # Mark the new location

        # An episode is done if the agent has reached the target
        if self.agent_location == self.target_location:
            terminated = True
        else:
            terminated = False
        
        truncated = False # We are not truncating episodes based on the step count

        # Return observation, reward, terminated, truncated, and info
        observation = {'agent': np.array(self.agent_location)}
        info = {}  # Add any relevant information here (e.g., additional metrics)
        
        return observation, reward, terminated, truncated, info

    ###########################################################################################################################

    def reward_mechanism(self, action):
        agent_coordinates = np.array([self.agent_location[0], self.agent_location[1]])
        target_coordinates = np.array([self.target_location[0], self.target_location[1]])

        if action == 0:
            prospective_coordinates = [self.agent_location[0] + 1, self.agent_location[1]]
            if prospective_coordinates[0] >= self.rows:
                prospective_coordinates[0] = self.rows - 1

            ##################################################################################################################
            
            if self.layout[prospective_coordinates[0]][self.agent_location[1]] == '#':
                return self.obstacle_hit_reward
            if self.layout[prospective_coordinates[0]][self.agent_location[1]] == 'T':
                return self.completion_reward
            return self._calculate_distance_reward(agent_coordinates, prospective_coordinates, target_coordinates)

        # Repeat similar logic for other actions (1, 2, 3)
        
        if action == 1:
            prospective_coordinates = [self.agent_location[0], self.agent_location[1] + 1]
            if prospective_coordinates[1] >= self.columns:
                prospective_coordinates[1] = self.columns - 1
            if self.layout[self.agent_location[0]][prospective_coordinates[1]] == '#':
                return self.obstacle_hit_reward
            if self.layout[self.agent_location[0]][prospective_coordinates[1]] == 'T':
                return self.completion_reward
            return self._calculate_distance_reward(agent_coordinates, prospective_coordinates, target_coordinates)

        if action == 2:
            prospective_coordinates = [self.agent_location[0] - 1, self.agent_location[1]]
            if prospective_coordinates[0] < 0:
                prospective_coordinates[0] = 0
            if self.layout[prospective_coordinates[0]][self.agent_location[1]] == '#':
                return self.obstacle_hit_reward
            if self.layout[prospective_coordinates[0]][self.agent_location[1]] == 'T':
                return self.completion_reward
            return self._calculate_distance_reward(agent_coordinates, prospective_coordinates, target_coordinates)

        if action == 3:
            prospective_coordinates = [self.agent_location[0], self.agent_location[1] - 1]
            if prospective_coordinates[1] < 0:
                prospective_coordinates[1] = 0
            if self.layout[self.agent_location[0]][prospective_coordinates[1]] == '#':
                return self.obstacle_hit_reward
            if self.layout[self.agent_location[0]][prospective_coordinates[1]] == 'T':
                return self.completion_reward
            return self._calculate_distance_reward(agent_coordinates, prospective_coordinates, target_coordinates)

    def _calculate_distance_reward(self, agent_coordinates, prospective_coordinates, target_coordinates):
        if np.linalg.norm(agent_coordinates - target_coordinates, ord=1) < np.linalg.norm(prospective_coordinates - target_coordinates, ord=1):
            return self.increase_dist_reward
        return self.reduce_dist_reward

    ###########################################################################################################################

    def render(self, mode = 'human'):
        print(self.layout)  # Print the layout with the agent's current position
        return

# %% [markdown]
# #### **Training Phase**

# %%
print("Initial Setup")
env = DiscDetCompatEnv(layout_RL_Learning, drone_location, target_location) # Load the environment
print(env.layout)

# Instantiate the model with improved hyperparameters
model = DQN('MultiInputPolicy', env, 
            verbose=1,
            learning_rate = 1e-2,    # Slightly lower learning rate
            buffer_size = 100000,    # Increase buffer size for more experience replay
            batch_size = 32,         # Batch size for more stable training
            learning_starts = 100,  # Start learning after 100 timesteps
            exploration_fraction = 0.5,  # Keep exploration high initially
            exploration_final_eps = 0.25,  # Final epsilon after decay
            gamma = 0.25)  # Discount factor (gamma) for the future reward

model.learn(total_timesteps = 20000, log_interval = 4) # Train the model with more timesteps and log interval for progress
# Out:
# Initial Setup
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 216       |
# |    ep_rew_mean      | -5.35e+06 |
# |    exploration_rate | 0.935     |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 547       |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 862       |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 2.17e+04  |
# |    n_updates        | 190       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 240       |
# |    ep_rew_mean      | -6.35e+06 |
# |    exploration_rate | 0.856     |
# | time/               |           |
# |    episodes         | 8         |
# |    fps              | 515       |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 1916      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 2.22e+04  |
# |    n_updates        | 453       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 220       |
# |    ep_rew_mean      | -6.02e+06 |
# |    exploration_rate | 0.802     |
# | time/               |           |
# |    episodes         | 12        |
# |    fps              | 446       |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 2634      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 1.33e+04  |
# |    n_updates        | 633       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 194       |
# |    ep_rew_mean      | -5.13e+06 |
# |    exploration_rate | 0.768     |
# | time/               |           |
# |    episodes         | 16        |
# |    fps              | 475       |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 3097      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 1.3e+04   |
# |    n_updates        | 749       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 171       |
# |    ep_rew_mean      | -4.45e+06 |
# |    exploration_rate | 0.743     |
# | time/               |           |
# |    episodes         | 20        |
# |    fps              | 482       |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 3425      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 3.72e+04  |
# |    n_updates        | 831       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 164       |
# |    ep_rew_mean      | -4.28e+06 |
# |    exploration_rate | 0.705     |
# | time/               |           |
# |    episodes         | 24        |
# |    fps              | 449       |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 3939      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 4.05e+04  |
# |    n_updates        | 959       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 157       |
# |    ep_rew_mean      | -4.02e+06 |
# |    exploration_rate | 0.671     |
# | time/               |           |
# |    episodes         | 28        |
# |    fps              | 409       |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 4393      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 2.11e+04  |
# |    n_updates        | 1073      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 161       |
# |    ep_rew_mean      | -4.15e+06 |
# |    exploration_rate | 0.613     |
# | time/               |           |
# |    episodes         | 32        |
# |    fps              | 370       |
# |    time_elapsed     | 13        |
# |    total_timesteps  | 5154      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 3.43e+04  |
# |    n_updates        | 1263      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 153       |
# |    ep_rew_mean      | -3.95e+06 |
# |    exploration_rate | 0.588     |
# | time/               |           |
# |    episodes         | 36        |
# |    fps              | 374       |
# |    time_elapsed     | 14        |
# |    total_timesteps  | 5491      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 2.32e+04  |
# |    n_updates        | 1347      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 147       |
# |    ep_rew_mean      | -3.81e+06 |
# |    exploration_rate | 0.56      |
# | time/               |           |
# |    episodes         | 40        |
# |    fps              | 381       |
# |    time_elapsed     | 15        |
# |    total_timesteps  | 5870      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 3.26e+04  |
# |    n_updates        | 1442      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 141       |
# |    ep_rew_mean      | -3.62e+06 |
# |    exploration_rate | 0.535     |
# | time/               |           |
# |    episodes         | 44        |
# |    fps              | 377       |
# |    time_elapsed     | 16        |
# |    total_timesteps  | 6202      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 1.81e+04  |
# |    n_updates        | 1525      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 142       |
# |    ep_rew_mean      | -3.75e+06 |
# |    exploration_rate | 0.488     |
# | time/               |           |
# |    episodes         | 48        |
# |    fps              | 374       |
# |    time_elapsed     | 18        |
# |    total_timesteps  | 6829      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 2.6e+04   |
# |    n_updates        | 1682      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 147       |
# |    ep_rew_mean      | -3.89e+06 |
# |    exploration_rate | 0.425     |
# | time/               |           |
# |    episodes         | 52        |
# |    fps              | 382       |
# |    time_elapsed     | 20        |
# |    total_timesteps  | 7664      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 5.22e+03  |
# |    n_updates        | 1890      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 146       |
# |    ep_rew_mean      | -4.02e+06 |
# |    exploration_rate | 0.387     |
# | time/               |           |
# |    episodes         | 56        |
# |    fps              | 378       |
# |    time_elapsed     | 21        |
# |    total_timesteps  | 8167      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 2.06e+04  |
# |    n_updates        | 2016      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 146       |
# |    ep_rew_mean      | -4.09e+06 |
# |    exploration_rate | 0.342     |
# | time/               |           |
# |    episodes         | 60        |
# |    fps              | 376       |
# |    time_elapsed     | 23        |
# |    total_timesteps  | 8779      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 1.98e+04  |
# |    n_updates        | 2169      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 147       |
# |    ep_rew_mean      | -4.28e+06 |
# |    exploration_rate | 0.293     |
# | time/               |           |
# |    episodes         | 64        |
# |    fps              | 372       |
# |    time_elapsed     | 25        |
# |    total_timesteps  | 9423      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 3.13e+04  |
# |    n_updates        | 2330      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 151       |
# |    ep_rew_mean      | -4.41e+06 |
# |    exploration_rate | 0.25      |
# | time/               |           |
# |    episodes         | 68        |
# |    fps              | 370       |
# |    time_elapsed     | 27        |
# |    total_timesteps  | 10256     |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 3.7e+04   |
# |    n_updates        | 2538      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 191       |
# |    ep_rew_mean      | -5.39e+06 |
# |    exploration_rate | 0.25      |
# | time/               |           |
# |    episodes         | 72        |
# |    fps              | 380       |
# |    time_elapsed     | 36        |
# |    total_timesteps  | 13741     |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 1.26e+04  |
# |    n_updates        | 3410      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 195       |
# |    ep_rew_mean      | -5.34e+06 |
# |    exploration_rate | 0.25      |
# | time/               |           |
# |    episodes         | 76        |
# |    fps              | 383       |
# |    time_elapsed     | 38        |
# |    total_timesteps  | 14809     |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 2.21e+04  |
# |    n_updates        | 3677      |
# -----------------------------------

# %% [markdown]
# #### **Testing Phase**

# %%
print("Initial Setup")
print(layout_RL_Learning)

# Test the model here

obs = env.reset()
print("Initial State: ", obs[0]['agent'])
counter = 0
for _ in range(1000):
    action, _states = model.predict(obs[0])
    observation, reward, terminated, truncated, info = env.step(action)
    print(f"Action: {action}, New State: {observation['agent']}, Reward: {reward}, Terminated: {terminated}")
    env.render()
    counter = counter + 1
    if terminated:
        break

print("Number of steps taken: ", counter)
# Out:
# Initial Setup
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Initial State:  [1 1]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: [2 1], Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: [2 1], Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: [2 2], Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' 'D' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: [1 2], Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: [2 1], Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: [2 1], Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# ...
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: [2 1], Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [2 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: [1 2], Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: [1 3], Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' 'D' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: [1 3], Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' 'D' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: [1 2], Reward: 10, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 3, New State: [1 1], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' '#' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' ' ' '#' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' '#' ' ' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' '#' '#' '#' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#']]
# Number of steps taken:  1000

# %% [markdown]
# ## **Case 2: Discrete Markov Decision Process with Probabilistic Reward**

# %% [markdown]
# ### **Environment Definition**

# %%
class DiscProbEnv(gym.Env):
    def __init__(self, layout, drone_location, target_location, completion_reward = 100000, obstacle_hit_reward = -100000,
                 reduce_dist_reward = 10, increase_dist_reward = -5, stay_reward = -1, wind_speed_bound_x = (-1, 1), wind_speed_bound_y = (-1, 1)):
        super(DiscProbEnv, self).__init__()  # Ensure compatibility by calling the parent constructor

        self.layout = layout # Layout is made an attribute of the object so that it can be used in the methods
        self.layout_duplicate = layout.copy() # Duplicate layout to prevent overwriting
        self.rows, self.columns = np.shape(layout) # Obtain the number of rows and columns
        self.raster_dict = raster_scan(layout) # Obtain the dictionary with the raster indexation
        self.start = drone_location # Starting position of the drone
        self.target_location = target_location # Target/ Delivery location
        self.agent_location = self.start # Initialize the agent location
        self.wind_speed_bound_x = wind_speed_bound_x # Wind speed bound in the x-direction
        self.wind_speed_bound_y = wind_speed_bound_y # Wind speed bound in the y-direction
        # self.step_count = 0 # Initialize the step count (optional)

        #######################################################################################################################
        
        # Rewards

        self.completion_reward = completion_reward
        self.obstacle_hit_reward = obstacle_hit_reward
        self.reduce_dist_reward = reduce_dist_reward
        self.increase_dist_reward = increase_dist_reward
        self.reduce_dist_reward = reduce_dist_reward
        self.stay_reward = stay_reward

        #######################################################################################################################

        # Observations are dictionaries with the agent's location. Note that the target's location is fixed.

        """
        
        We prevent the drone from running over obstacles with the reward mechanism.
        
        """
        
        self.observation_space = spaces.Dict(
            {
                "agent": spaces.MultiDiscrete([self.rows, self.columns])
            }
        )

        #######################################################################################################################

        self.action_space = spaces.Discrete(5) # We have 5 actions, corresponding to "right", "up", "left", "down", and "stay put"

        """
        
        The following dictionary maps abstract actions from `self.action_space` to 
        the direction we will walk in if that action is taken.
        I.e., 0 corresponds to "right," 1 to "up" etc.
        
        """
        
        self.action_to_direction = {
            0: np.array([1, 0]),
            1: np.array([0, 1]),
            2: np.array([-1, 0]),
            3: np.array([0, -1]),
            4: np.array([0, 0])
        }

    ###########################################################################################################################    

    def reset(self, seed = None, **kwargs):
    
        super().reset(seed = seed) # Set the seed for reproducibility
        if seed is not None:
            np.random.seed(seed)

        self.agent_location = self.start # Reset agent location
        self.layout = self.layout_duplicate.copy() # Reset the layout

        # Return the observation and an empty dictionary as additional info (as required by Gym)
        return {'agent': np.array(self.agent_location)}, {}
    
    ###########################################################################################################################

    def step(self, action):
        action = int(action)  # Ensure action is an integer
        reward = self.reward_mechanism(action)
        if reward == self.obstacle_hit_reward:
            terminated = False
            truncated = False
            observation = {'agent': np.array(self.agent_location)}
            info = {}  # Add any relevant information here (e.g., additional metrics)
            return observation, reward, terminated, truncated, info
        
        direction = self.action_to_direction[action]  # Map the action to the walking direction

        # layout_copy = self.layout.copy()
        self.layout[self.agent_location[0], self.agent_location[1]] = ' '  # Clear current location
        self.agent_location =   (
                                    np.clip(self.agent_location[0] + direction[0], 1, self.rows - 2), 
                                    np.clip(self.agent_location[1] + direction[1], 1, self.columns - 2)
                                )  # Update the agent location
        self.layout[self.agent_location[0], self.agent_location[1]] = 'D'  # Mark the new location

        # An episode is done if the agent has reached the target
        if self.agent_location == self.target_location:
            terminated = True
        else:
            terminated = False
        
        truncated = False # We are not truncating episodes based on the step count

        # Return observation, reward, terminated, truncated, and info
        observation = {'agent': np.array(self.agent_location)}
        info = {}  # Add any relevant information here (e.g., additional metrics)
        
        return observation, reward, terminated, truncated, info

    ###########################################################################################################################

    def reward_mechanism(self, action):
        agent_coordinates = np.array([self.agent_location[0], self.agent_location[1]])
        target_coordinates = np.array([self.target_location[0], self.target_location[1]])

        if action == 0:
            prospective_coordinates = [self.agent_location[0] + 1, self.agent_location[1]]
            if prospective_coordinates[0] >= self.rows:
                prospective_coordinates[0] = self.rows - 1

            ##################################################################################################################
            
            if self.layout[prospective_coordinates[0]][self.agent_location[1]] == '#':
                return self.obstacle_hit_reward
            if self.layout[prospective_coordinates[0]][self.agent_location[1]] == 'T':
                return self.completion_reward
            return self._calculate_distance_reward(agent_coordinates, prospective_coordinates, target_coordinates) + np.random.uniform(self.wind_speed_bound_x[0], self.wind_speed_bound_x[1])

        # Repeat similar logic for other actions (1, 2, 3)
        
        if action == 1:
            prospective_coordinates = [self.agent_location[0], self.agent_location[1] + 1]
            if prospective_coordinates[1] >= self.columns:
                prospective_coordinates[1] = self.columns - 1
            if self.layout[self.agent_location[0]][prospective_coordinates[1]] == '#':
                return self.obstacle_hit_reward
            if self.layout[self.agent_location[0]][prospective_coordinates[1]] == 'T':
                return self.completion_reward
            return self._calculate_distance_reward(agent_coordinates, prospective_coordinates, target_coordinates) + np.random.uniform(self.wind_speed_bound_y[0], self.wind_speed_bound_y[1])

        if action == 2:
            prospective_coordinates = [self.agent_location[0] - 1, self.agent_location[1]]
            if prospective_coordinates[0] < 0:
                prospective_coordinates[0] = 0
            if self.layout[prospective_coordinates[0]][self.agent_location[1]] == '#':
                return self.obstacle_hit_reward
            if self.layout[prospective_coordinates[0]][self.agent_location[1]] == 'T':
                return self.completion_reward
            return self._calculate_distance_reward(agent_coordinates, prospective_coordinates, target_coordinates) + np.random.uniform(self.wind_speed_bound_x[0], self.wind_speed_bound_x[1])

        if action == 3:
            prospective_coordinates = [self.agent_location[0], self.agent_location[1] - 1]
            if prospective_coordinates[1] < 0:
                prospective_coordinates[1] = 0
            if self.layout[self.agent_location[0]][prospective_coordinates[1]] == '#':
                return self.obstacle_hit_reward
            if self.layout[self.agent_location[0]][prospective_coordinates[1]] == 'T':
                return self.completion_reward
            return self._calculate_distance_reward(agent_coordinates, prospective_coordinates, target_coordinates) + np.random.uniform(self.wind_speed_bound_y[0], self.wind_speed_bound_y[1])
        
        if action == 4:
            return self.stay_reward

    def _calculate_distance_reward(self, agent_coordinates, prospective_coordinates, target_coordinates):
        if np.linalg.norm(agent_coordinates - target_coordinates, ord=1) < np.linalg.norm(prospective_coordinates - target_coordinates, ord = 1):
            return self.increase_dist_reward
        return self.reduce_dist_reward

    ###########################################################################################################################

    def render(self, mode = 'human'):
        print(self.layout)  # Print the layout with the agent's current position
        return

# %% [markdown]
# ### **Training Phase**

# %%
print("Initial Setup")
layout_size = (8, 8)
drone_location = (1, 1)
target_location = (6, 6)
layout_RL_Learning = strictly_solvable(layout_size, drone_location, target_location, obstacle_density = 0.1) # Generate a solvable layout
env = DiscProbEnv(layout_RL_Learning, drone_location, target_location) # Load the environment
print(env.layout)

# Instantiate the model with improved hyperparameters
# model = DQN('MultiInputPolicy', env, 
#             verbose=1,
#             learning_rate = 1e-2,    # Slightly lower learning rate
#             buffer_size = 100000,    # Increase buffer size for more experience replay
#             batch_size = 32,         # Batch size for more stable training
#             learning_starts = 100,  # Start learning after 100 timesteps
#             exploration_fraction = 0.5,  # Keep exploration high initially
#             exploration_final_eps = 0.25,  # Final epsilon after decay
#             gamma = 0.8)  # Discount factor (gamma) for the future reward

model = DQN('MultiInputPolicy', env, verbose=1)

model.learn(total_timesteps = 10000, log_interval = 4) # Train the model with more timesteps and log interval for progress
# Out:
# Initial Setup
# Iterations take:  0
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -2.3e+06 |
# |    exploration_rate | 0.601    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 933      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 420      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.81e+04 |
# |    n_updates        | 79       |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 96.1      |
# |    ep_rew_mean      | -3.54e+06 |
# |    exploration_rate | 0.269     |
# | time/               |           |
# |    episodes         | 8         |
# |    fps              | 626       |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 769       |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.38e+04  |
# |    n_updates        | 167       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 77.2      |
# |    ep_rew_mean      | -3.16e+06 |
# |    exploration_rate | 0.12      |
# | time/               |           |
# |    episodes         | 12        |
# |    fps              | 574       |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 926       |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.38e+04  |
# |    n_updates        | 206       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 60.8      |
# |    ep_rew_mean      | -2.34e+06 |
# |    exploration_rate | 0.0757    |
# | time/               |           |
# |    episodes         | 16        |
# |    fps              | 556       |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 973       |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.81e+04  |
# |    n_updates        | 218       |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | -5.5e+06 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 553      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2185     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.63e+04 |
# |    n_updates        | 521      |
# ----------------------------------

# %% [markdown]
# ### **Testing Phase**

# %%
print("Initial Setup")
print(layout_RL_Learning)

# Test the model here

obs = env.reset()
print("Initial State: ", obs[0]['agent'])
counter = 0
for _ in range(100):
    action, _states = model.predict(obs[0])
    observation, reward, terminated, truncated, info = env.step(action)
    print(f"Action: {action}, New State: {observation['agent']}, Reward: {reward}, Terminated: {terminated}")
    env.render()
    counter = counter + 1
    if terminated:
        break

print("Number of steps taken: ", counter)
# Out:
# Initial Setup
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Initial State:  [1 1]
# Action: 4, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 1], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 1, New State: [1 2], Reward: 9.270894476488388, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: [1 2], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 2, New State: [1 2], Reward: -100000, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [1 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' 'D' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 0, New State: [2 2], Reward: 9.012747659647767, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' 'D' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [2 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' 'D' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [2 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' 'D' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [2 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' 'D' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [2 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' 'D' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [2 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' 'D' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [2 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' 'D' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [2 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' 'D' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [2 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' 'D' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [2 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' 'D' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [2 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' 'D' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [2 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' 'D' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [2 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' 'D' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: 4, New State: [2 2], Reward: -1, Terminated: False
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' 'D' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' '#' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Number of steps taken:  100

# %% [markdown]
# ## **Case 3: Continuous Markov Decision Process with Deterministic Reward**

# %% [markdown]
# ### **Environment Definition**

# %%
class ContDetEnv(gym.Env):
    def __init__(self, layout, drone_location, target_location, initial_velocity = np.array([0, 0]), completion_reward = 100000, 
                 obstacle_hit_reward = -100000, reduce_dist_reward = 10, increase_dist_reward = -5, stand_still_reward = -1, speed_limit_x = 5,
                 speed_limit_y = 5, acceleration_limit_x = 2, acceleration_limit_y = 2, time_step = 0.5, distance_threshold = 0.1):
        super(ContDetEnv, self).__init__()  # Ensure compatibility by calling the parent constructor

        self.layout = layout # Layout is made an attribute of the object so that it can be used in the methods
        self.layout_duplicate = layout.copy() # Duplicate layout to prevent overwriting
        self.rows, self.columns = np.shape(layout) # Obtain the number of rows and columns
        self.raster_dict = raster_scan(layout) # Obtain the dictionary with the raster indexation
        self.start = drone_location # Starting position of the drone
        self.target_location = np.array(target_location) # Target/ Delivery location
        self.agent_location = np.array([self.start[0], self.start[1]]) # Initialize the agent location
        # self.step_count = 0 # Initialize the step count (optional)
        self.velocity = initial_velocity # Initialize the velocity of the agent
        self.speed_limit_x = speed_limit_x # Speed limit in the x-direction
        self.speed_limit_y = speed_limit_y # Speed limit in the y-direction
        self.time_step = time_step # Time step for the simulation
        self.distance_threshold = distance_threshold # Distance threshold for the agent to reach the target

        #######################################################################################################################
        
        # Rewards

        self.completion_reward = completion_reward
        self.obstacle_hit_reward = obstacle_hit_reward
        self.reduce_dist_reward = reduce_dist_reward
        self.increase_dist_reward = increase_dist_reward
        self.reduce_dist_reward = reduce_dist_reward
        self.stand_still_reward = stand_still_reward

        #######################################################################################################################

        # Observations are dictionaries with the agent's location. Note that the target's location is fixed.

        """
        
        We prevent the drone from running over obstacles with the reward mechanism.
        
        """

        self.observation_space = spaces.Dict({
            "agent_position": spaces.Box(low=np.array([0, 0]), high=np.array([self.rows, self.columns]), dtype = np.float32),
            "agent_velocity": spaces.Box(low = np.array([-self.speed_limit_x, -self.speed_limit_y]), 
                                   high = np.array([self.speed_limit_x, self.speed_limit_y]), dtype = np.float32)
        })

        #######################################################################################################################

        self.action_space = spaces.Box(low = np.array([-acceleration_limit_x, -acceleration_limit_y]),
                                        high = np.array([acceleration_limit_x, acceleration_limit_y]), dtype = np.float32)

    ###########################################################################################################################    

    def reset(self, seed = None, **kwargs):
    
        super().reset(seed = seed) # Set the seed for reproducibility
        if seed is not None:
            np.random.seed(seed)

        self.agent_location = self.start # Reset agent location
        self.velocity = np.array([0, 0]) # Reset the velocity
        self.layout = self.layout_duplicate.copy() # Reset the layout

        # Return the observation and an empty dictionary as additional info (as required by Gym)
        return {'agent_position': np.array(self.agent_location), 'agent_velocity': np.array(self.velocity)}, {}
    
    ###########################################################################################################################

    def step(self, action):

        position = self.agent_location
        velocity = self.velocity
        acceleration_x, acceleration_y = action
        
        # Update velocity and position
        velocity[0] = velocity[0] + (acceleration_x * self.time_step)
        velocity[1] = velocity[1] + (acceleration_y * self.time_step)
        position_new = position + (velocity * self.time_step)

        # Check if there are obstacles within the distance_threshold from the new position
        
        possible_obstacle_coordinates = {
                                            "right_up": (np.ceil(position_new[0]), np.ceil(position_new[1])),
                                            "right_down": (np.ceil(position_new[0]), np.floor(position_new[1])),
                                            "left_up": (np.floor(position_new[0]), np.ceil(position_new[1])),
                                            "left_down": (np.floor(position_new[0]), np.floor(position_new[1]))
                                        }

        for value in possible_obstacle_coordinates.values():
            if value[0] >= self.rows or value[1] >= self.columns or value[0] < 0 or value[1] < 0:
                reward = self.obstacle_hit_reward
                terminated = False
                truncated = False
                observation = {'agent_position': position, 'agent_velocity': velocity}
                info = {}  # Add any relevant information here (e.g., additional metrics)
                return observation, reward, terminated, truncated, info
            if self.layout[int(value[0]), int(value[1])] == '#':
                coordinate = np.array([value[0], value[1]])
                if np.linalg.norm(position_new - coordinate) < self.distance_threshold:
                    reward = self.obstacle_hit_reward
                    terminated = False
                    truncated = False
                    observation = {'agent_position': position, 'agent_velocity': velocity}
                    info = {}  # Add any relevant information here (e.g., additional metrics)
                    return observation, reward, terminated, truncated, info

        # Update the agent's position and velocity

        self.agent_location = position_new
        self.velocity = velocity
        if np.linalg.norm(self.agent_location - self.target_location) < np.linalg.norm(position - self.target_location):
            reward = self.reduce_dist_reward
            terminated = False
            truncated = False
            observation = {'agent_position': position_new, 'agent_velocity': velocity}
            info = {}
            return observation, reward, terminated, truncated, info
        
        if np.linalg.norm(self.agent_location - self.target_location) > np.linalg.norm(position - self.target_location):
            reward = self.increase_dist_reward
            terminated = False
            truncated = False
            observation = {'agent_position': position_new, 'agent_velocity': velocity}
            info = {}
            return observation, reward, terminated, truncated, info

        # An episode is done if the agent is within the distance threshold from the target

        if np.linalg.norm(self.agent_location - self.target_location) < self.distance_threshold:
            terminated = True
            truncated = False
            reward = self.completion_reward
            observation = {'agent_position': np.array(self.agent_location), 'agent_velocity': self.velocity}
            info = {}  # Add any relevant information here (e.g., additional metrics)
            return observation, reward, terminated, truncated, info
        
        terminated = False
        truncated = False
        reward = self.stand_still_reward
        observation = {'agent_position': np.array(self.agent_location), 'agent_velocity': self.velocity}
        info = {}  # Add any relevant information here (e.g., additional metrics)
        return observation, reward, terminated, truncated, info

    ###########################################################################################################################

    def render(self, mode = 'human'):
        print(self.layout)  # Print the layout with the agent's current position
        print("Velocity of the Agent: ", self.velocity) # Print the velocity of the agent
        print("Position of the Agent: ", self.agent_location) # Print the agent's location
        return

# %% [markdown]
# ### **Training Phase**

# %%
layout_size = (8, 8)
drone_location = (1, 1)
target_location = (6, 6)
layout_RL_Learning = strictly_solvable(layout_size, drone_location, target_location, obstacle_density = 0.2) # Generate a solvable layout
print("Initial Setup")
env = ContDetEnv(layout_RL_Learning, drone_location, target_location) # Load the environment
print(env.layout)

# Instantiate the model with improved hyperparameters
model = PPO('MultiInputPolicy', env, verbose = 1)

model.learn(total_timesteps = 10000, log_interval = 10) # Train the model with more timesteps and log interval for progress
# Out:
# Iterations take:  0
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' '#' ' ' '#' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Initial Setup
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' '#' ' ' '#' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ### **Testing Phase**

# %%
print("Initial Setup")
print(layout_RL_Learning)

# Test the model here

obs = env.reset()
counter = 0
for _ in range(10000):
    action, _states = model.predict(obs[0])
    observation, reward, terminated, truncated, info = env.step(action)
    print(f"Action: {action}, New Position: {observation['agent_position']}, New Velocity: {observation['agent_velocity']}, Reward: {reward}, Terminated: {terminated}")
    # env.render()
    counter = counter + 1
    if terminated:
        break

print("Number of steps taken: ", counter)
# Out:
# Initial Setup
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' '#' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' '#' ' ' '#' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' ' ' ' ' ' ' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: [-0.14763476  0.2911046 ], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.53862214 1.2345076 ], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.3613651  -0.18476215], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.1201079 1.5627996], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.22943336 -1.0974171 ], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.6668606  1.9366153], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.86026174 -0.25805628], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.06773571 -0.54506665], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.14185242 -0.4193645 ], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.4527362 -0.9287584], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.04275393 -0.57966524], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.9298457   0.28759497], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.43365046  1.1790574 ], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.49280524 -0.44891313], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.30407056 -0.6532852 ], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.67609996 -0.48527145], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.11334633  0.44724855], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.31499442 1.5591826 ], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.30802718 -1.2459072 ], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.24176915 -1.6488961 ], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.0895319  -0.26874432], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.1658299 -1.1202803], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.90513986  0.906198  ], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.9824372 0.9825142], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.39214218  0.09796295], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.4871389   0.25459534], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-2.         -0.46233988], New Position: [0.5 1. ], New Velocity: [-1  0], Reward: -5, Terminated: False
# Action: [-1.3264626  1.246697 ], New Position: [0.5 1. ], New Velocity: [-1  0], Reward: -100000, Terminated: False
# Action: [-0.50051934  0.7800929 ], New Position: [0.5 1. ], New Velocity: [-1  0], Reward: -100000, Terminated: False
# Action: [0.3975741  0.70897496], New Position: [0.5 1. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.0963324  -0.46698987], New Position: [0.5 1. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.4414938 -1.4797019], New Position: [0.5 1. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.43091622  2.        ], New Position: [0.5 1.5], New Velocity: [0 1], Reward: 10, Terminated: False
# Action: [-0.51377153  0.66564405], New Position: [0.5 2. ], New Velocity: [0 1], Reward: 10, Terminated: False
# Action: [0.25217363 1.0743928 ], New Position: [0.5 2.5], New Velocity: [0 1], Reward: 10, Terminated: False
# Action: [ 0.48886108 -0.32982463], New Position: [0.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.0553242   0.09659207], New Position: [0.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.3369653 -1.2604574], New Position: [0.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.2090511  0.93798256], New Position: [0.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.39032727 -0.5187859 ], New Position: [0.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.8668316  0.07017519], New Position: [0.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7558046 -1.0300738], New Position: [0.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.7898674 1.3697307], New Position: [0.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.43462637 0.06368037], New Position: [0.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.9085691  0.3769784], New Position: [0.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [2.        1.6383476], New Position: [1.  2.5], New Velocity: [1 0], Reward: 10, Terminated: False
# Action: [-0.89017045  2.        ], New Position: [1.  2.5], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [0.5615404  0.17259361], New Position: [1.  2.5], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-0.5250979  -0.72098625], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.7984599  -0.46208152], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.8098712  0.7836274], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.26445195 1.9150255 ], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.31268314 -1.9731401 ], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.8549884 -1.242641 ], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.5823543  -0.56622565], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.321902  1.2460792], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.2675577 -1.7893947], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.4168737  0.44903797], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7715351  -0.18167868], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.2003487  0.02327957], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.61866534 -0.99741167], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.2840031  0.7031783], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.6692022  -0.59870136], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.17361642 -0.48256022], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 2.        -0.6288693], New Position: [1.5 2.5], New Velocity: [1 0], Reward: 10, Terminated: False
# Action: [-0.12140653  0.9633464 ], New Position: [1.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.8792241 -0.477947 ], New Position: [1.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.5087353 0.5710134], New Position: [1.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.40091988 0.66172427], New Position: [1.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.7845344 2.       ], New Position: [1.5 3. ], New Velocity: [0 1], Reward: 10, Terminated: False
# Action: [-1.277808  2.      ], New Position: [1.5 4. ], New Velocity: [0 2], Reward: 10, Terminated: False
# Action: [0.00548344 0.86278903], New Position: [1.5 5. ], New Velocity: [0 2], Reward: 10, Terminated: False
# Action: [1.7418586 0.2923207], New Position: [1.5 6. ], New Velocity: [0 2], Reward: 10, Terminated: False
# Action: [ 1.3602288  -0.33941454], New Position: [1.5 6.5], New Velocity: [0 1], Reward: -5, Terminated: False
# Action: [-0.99382746 -0.8229241 ], New Position: [1.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.1900525 1.0704232], New Position: [1.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.11018592 -1.1230639 ], New Position: [1.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.3066498 1.0720277], New Position: [1.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.243453   0.32611233], New Position: [1.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.4699614  0.44924983], New Position: [1.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.39248773 -0.16145238], New Position: [1.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.46099043 -0.2517824 ], New Position: [1.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.55408174 -0.3370037 ], New Position: [1.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.52906835 -0.8412964 ], New Position: [1.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7041252 -1.8354584], New Position: [1.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.2713158  0.25761953], New Position: [1.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.48612174 1.0145354 ], New Position: [1.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.95611537 -0.79480934], New Position: [1.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.05022062 -0.7072524 ], New Position: [1.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.2386128 -1.0375725], New Position: [1.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 2.         -0.07592969], New Position: [2.  6.5], New Velocity: [1 0], Reward: 10, Terminated: False
# Action: [-0.89147204 -1.3718222 ], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.8969717 -1.2674061], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.2768302  -0.27427378], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.98341036 -1.7249264 ], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.15790805 2.        ], New Position: [2.  6.5], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-1.6711105  1.2901425], New Position: [2.  6.5], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [ 0.07585936 -0.5756573 ], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7949958 -1.9720552], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.1772254 0.7235631], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.4020226  0.33956373], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.3478694 -1.2630779], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.3680027  1.0992289], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.16309094 -0.2785643 ], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.00178932 -0.19162615], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.519477   -0.56796706], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.16812426 -0.6417    ], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.0607158  0.02014846], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.28631634 -0.6449279 ], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.556495  -1.0988822], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.1802548  -0.33410588], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.67734003 -0.46205026], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.06403081 -0.16180797], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.78314775  0.07744325], New Position: [2.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.11556832 -2.        ], New Position: [2. 6.], New Velocity: [ 0 -1], Reward: 10, Terminated: False
# Action: [-1.8020573  2.       ], New Position: [2. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.5627255 -1.6595371], New Position: [2. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.94068885 -0.8875261 ], New Position: [2. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.95808244 0.20363168], New Position: [2. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.3151581 0.7148102], New Position: [2. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.2211009 0.0729714], New Position: [2. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.04631905  1.4444944 ], New Position: [2. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7138421 -0.6166396], New Position: [2. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.10200503  1.1165588 ], New Position: [2. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.06670304  0.2065021 ], New Position: [2. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 2.        -1.7413656], New Position: [2.5 6. ], New Velocity: [1 0], Reward: 10, Terminated: False
# Action: [-0.7184705  0.6862585], New Position: [2.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.3603529 0.543867 ], New Position: [2.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.5013274  0.02463968], New Position: [2.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.88387835  1.0465636 ], New Position: [2.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.07802815 -0.3140819 ], New Position: [2.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.383055   1.1083493], New Position: [2.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.93785083 -1.5220317 ], New Position: [2.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [2.        1.1864884], New Position: [3. 6.], New Velocity: [1 0], Reward: 10, Terminated: False
# Action: [-0.624725   -0.25724345], New Position: [3. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.5208916  0.23614176], New Position: [3. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.17752299 -0.8723803 ], New Position: [3. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.65817714 -0.36856875], New Position: [3. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7881523   0.05126384], New Position: [3. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.45151657 1.0471116 ], New Position: [3. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.21805333  0.8090473 ], New Position: [3. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.36804333 0.23998731], New Position: [3. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.9107172  2.       ], New Position: [3.  6.5], New Velocity: [0 1], Reward: -5, Terminated: False
# Action: [0.983677   0.07219175], New Position: [3.  6.5], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [2.         0.41920042], New Position: [3.5 7. ], New Velocity: [1 1], Reward: 10, Terminated: False
# Action: [-0.37337428 -0.8122468 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.04234647 1.2519673 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.92797637 -0.95038044], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.11986492 2.        ], New Position: [3.5 7. ], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-0.33700556  1.6083452 ], New Position: [3.5 7. ], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [0.27042466 1.3360661 ], New Position: [3.5 7. ], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [ 0.43353754 -0.18248227], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.873721   0.00352285], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.28134152 -0.42222822], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.24047   0.1378013], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.6431826  1.2217876], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.5004597 -0.8946327], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.06998976 -0.61962616], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.28335202  1.2394022 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.27879223 1.2018782 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.6594896 1.4666798], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.1568564   0.04279953], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.8497933   0.27392766], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.65207464 -0.11379633], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.41766176 -1.4391516 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.4914373  2.       ], New Position: [3.5 7. ], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-0.42039436  0.4357776 ], New Position: [3.5 7. ], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-0.33851522 -0.9896801 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.27579033  0.26426297], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.47168043 -1.1537151 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.690251   -0.44636825], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.54915684 -0.6960513 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.11828294 -0.70152503], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7101258  -0.97715724], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.6350795  0.20267153], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.5648375  -0.36464968], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.6874873 -2.       ], New Position: [3.5 6.5], New Velocity: [ 0 -1], Reward: 10, Terminated: False
# Action: [ 0.46103555 -1.0945889 ], New Position: [3.5 6. ], New Velocity: [ 0 -1], Reward: 10, Terminated: False
# Action: [-0.31176358  1.2179269 ], New Position: [3.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.36711574 0.13741687], New Position: [3.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.5357453 2.       ], New Position: [3.5 6.5], New Velocity: [0 1], Reward: -5, Terminated: False
# Action: [0.211712   0.33878198], New Position: [3.5 7. ], New Velocity: [0 1], Reward: -5, Terminated: False
# Action: [1.0093473  0.33343384], New Position: [3.5 7. ], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-0.64162827  0.3274643 ], New Position: [3.5 7. ], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-0.54796886  1.5094117 ], New Position: [3.5 7. ], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [0.49763858 0.8145161 ], New Position: [3.5 7. ], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [0.91281086 0.04796582], New Position: [3.5 7. ], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-0.04984133  0.84577906], New Position: [3.5 7. ], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-0.26321325 -1.1221571 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.72312105 -1.3374944 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.00830541 1.2784914 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.32903016 -0.5628368 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.4551394  -0.26499724], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.2222161  -0.33848292], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.4068415  1.4138747], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.513472   0.31231898], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.89695585 0.04110113], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.5109953  -0.00371509], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.9121331  -0.07797029], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.0782613 -1.1092695], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [2.         0.37287575], New Position: [3.5 7. ], New Velocity: [1 0], Reward: -100000, Terminated: False
# Action: [-0.21335702  0.04136215], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.301191  -1.4882945], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.701642 1.346345], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.08619104 -1.1998549 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.4780793 1.2701856], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-2.        -0.5680618], New Position: [3.5 7. ], New Velocity: [-1  0], Reward: -100000, Terminated: False
# Action: [ 0.55271184 -0.48572034], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7184382  0.5997016], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.75920576  0.08082847], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.3520745 -1.2819304], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.81377435 1.1104146 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.24141945 -1.6920547 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.74777055 -0.40286782], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.40268198 -1.1563187 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.15096207 -0.6439952 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.16816261 -0.66470957], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.0489827  -0.59253776], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.99222374 -0.86546737], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.34542933 -1.1600828 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.6105944  -0.08791161], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.8447819  0.15191148], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.0199432 -1.5665474], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.69776255 -0.88265866], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.39477894 -0.3456316 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.537542   -0.99531966], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.18630207 1.0825899 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.54174745 -1.6688337 ], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7927878  0.5000577], New Position: [3.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.0194085 -2.       ], New Position: [3.5 6.5], New Velocity: [ 0 -1], Reward: 10, Terminated: False
# Action: [-0.5938845   0.21079476], New Position: [3.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.38733146 0.83968014], New Position: [3.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.82735157 -1.6705744 ], New Position: [3.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.8958168   0.03652862], New Position: [3.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.72341895  0.6844797 ], New Position: [3.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-2.0000000e+00  1.0262295e-03], New Position: [3.  6.5], New Velocity: [-1  0], Reward: -5, Terminated: False
# Action: [0.25445703 0.7603217 ], New Position: [3.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-2.        1.479402], New Position: [2.5 6.5], New Velocity: [-1  0], Reward: -5, Terminated: False
# Action: [ 0.2431083  -0.46669772], New Position: [2.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.4878967 -1.8171058], New Position: [2.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.1851335  1.2095566], New Position: [2.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.1139919 -0.5417735], New Position: [2.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.7212011 0.7604536], New Position: [2.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.55471987 -0.23719105], New Position: [2.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.58596736 -0.20829397], New Position: [2.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.4311882   0.32206094], New Position: [2.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.76793873 1.1414785 ], New Position: [2.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.9535557  1.5340662], New Position: [2.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.25928122 -0.9763419 ], New Position: [2.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.47187087 -0.78488076], New Position: [2.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7624235  -0.34780145], New Position: [2.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.13578066 -0.64685005], New Position: [2.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.25372362 -2.        ], New Position: [2.5 6. ], New Velocity: [ 0 -1], Reward: 10, Terminated: False
# Action: [-0.09752905 -0.1162845 ], New Position: [2.5 5.5], New Velocity: [ 0 -1], Reward: -5, Terminated: False
# Action: [-0.9883328   0.40524775], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.6004704 0.5918355], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.0651656  -0.19365111], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.9719061 -1.3633295], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.22737814 0.8808399 ], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.31744957  0.30220938], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-2.         0.7863759], New Position: [2.  5.5], New Velocity: [-1  0], Reward: -5, Terminated: False
# Action: [-0.67711174 -0.15090752], New Position: [1.5 5.5], New Velocity: [-1  0], Reward: -5, Terminated: False
# Action: [-0.29613146 -0.04141459], New Position: [1.  5.5], New Velocity: [-1  0], Reward: -5, Terminated: False
# Action: [-0.62917584 -0.47220582], New Position: [0.5 5.5], New Velocity: [-1  0], Reward: -5, Terminated: False
# Action: [1.084349   0.99415296], New Position: [0.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.37523785  0.45502266], New Position: [0.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.35887977 -0.8493295 ], New Position: [0.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.9252588  0.65844965], New Position: [0.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.78616375 -1.4586365 ], New Position: [0.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.48654285  0.01851644], New Position: [0.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.71796864 0.20407581], New Position: [0.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.41971532 2.        ], New Position: [0.5 6. ], New Velocity: [0 1], Reward: 10, Terminated: False
# Action: [ 2.        -1.4310383], New Position: [1. 6.], New Velocity: [1 0], Reward: 10, Terminated: False
# Action: [-1.0574374   0.36681223], New Position: [1. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.08100392 -0.6386634 ], New Position: [1. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.43999466 0.763271  ], New Position: [1. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.64329094 0.46391803], New Position: [1. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.7850339 2.       ], New Position: [1.  6.5], New Velocity: [0 1], Reward: -5, Terminated: False
# Action: [-0.7147489   0.17959033], New Position: [1.  6.5], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [0.5974157 0.3305613], New Position: [1.  6.5], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-0.3031239  0.9583374], New Position: [1.  6.5], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-1.4996694  0.5448569], New Position: [1.  6.5], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-1.4629222  -0.68430984], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.03049659 -0.10222287], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.2989894 1.2162002], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.66265553 -2.        ], New Position: [1. 6.], New Velocity: [ 0 -1], Reward: 10, Terminated: False
# Action: [-0.871215  -1.9505601], New Position: [1.  5.5], New Velocity: [ 0 -1], Reward: -5, Terminated: False
# Action: [-0.20510717  0.6764575 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.2774236   0.14143376], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.3215277  -0.83305556], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.29933012  0.61950094], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.7303299 -0.4223794], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.39585668  0.5736411 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.1212167 -0.7776571], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.2137202 -0.7432209], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.03671548 -1.2686652 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.11043108  0.6376769 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.22961389 1.003789  ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.31809226 0.587674  ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.08513455 0.11079188], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.36866307 -1.7441772 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.11066356  0.00256773], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.9648567  0.49228138], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.5196365  1.5211124], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.9661965  -0.71398854], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.1416218 0.670508 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.30509293 0.52889925], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.66736716 -0.82137835], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.85910016 -0.15949844], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.30029967 -1.592452  ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.2191267 1.5404786], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.3156357 -1.0365655], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.2394447  1.3475918], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.34142527 1.1365749 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.04480628 1.3342764 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.40482786 -0.29994977], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.6082188  1.7282373], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.34143892  0.58071506], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.51159644 -0.02366602], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.2904154  -0.83169067], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.0030601  -0.64277685], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.3850638  0.887822 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.7850304  0.58523387], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.30107644 -1.2828931 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.7479837  1.4508978], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.941176  -1.5178676], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.52965355  1.2335056 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.7918032 -1.830899 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.6108412   0.23515275], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.7497618 -1.4453421], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.19512895 -0.7925766 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.11513439 -0.700409  ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.7760634 -1.235434 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.03747118 0.05962714], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.4003073 -1.2008358], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.2092305  0.03119325], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.30022356  0.3337636 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.28947544 -1.2497597 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.2301731  0.04344159], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.8051507 1.005556 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.6664764 0.5990695], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.1875718  0.15683044], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.3898119  -0.04307796], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.3902621  -0.07866575], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.1998051   0.97155666], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.6837045  0.94763356], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.42748415  0.1438275 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.066042   0.4273011], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.4435705  1.6081343], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.6306381  1.672718 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.32264438 -0.47343075], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.25401723  1.8975501 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.7235551 0.9908943], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.1444202  0.93394905], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.77165896 -0.4326309 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.532032   1.3655726], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.8184323 -0.6244523], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.1426682 1.7516704], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.24298175 0.39111763], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.64625037 -0.36188668], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.0400987  0.6235513], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.12754104  1.4869962 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.55149955 -0.52509266], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.18487689  0.42103752], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.20240714  0.32170606], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.08374974 -1.3496698 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.4986923 -1.4114277], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.55354226 0.34196237], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.82053006  0.9270131 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.12236036 -0.10338053], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.77197015 -0.34736937], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [2.        0.5909372], New Position: [1.5 5.5], New Velocity: [1 0], Reward: 10, Terminated: False
# Action: [-0.08423945  0.222537  ], New Position: [1.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-2.          0.54470664], New Position: [1.  5.5], New Velocity: [-1  0], Reward: -5, Terminated: False
# Action: [-0.02464718 -0.4893348 ], New Position: [0.5 5.5], New Velocity: [-1  0], Reward: -5, Terminated: False
# Action: [-0.7133502  -0.75175583], New Position: [0.  5.5], New Velocity: [-1  0], Reward: -5, Terminated: False
# Action: [-0.52615285 -0.59478086], New Position: [0.  5.5], New Velocity: [-1  0], Reward: -100000, Terminated: False
# Action: [-0.09446004 -0.7103483 ], New Position: [0.  5.5], New Velocity: [-1  0], Reward: -100000, Terminated: False
# Action: [-0.5345371   0.00927245], New Position: [0.  5.5], New Velocity: [-1  0], Reward: -100000, Terminated: False
# Action: [0.12162827 2.        ], New Position: [0.  5.5], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-0.9142598 -1.5468643], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.80400276  1.0518115 ], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.1040155 1.1376077], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.50549513 -0.93630564], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.49135393 -0.53764206], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.5780738 -1.2702025], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.0308511 -0.7201942], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.7118771  0.08963064], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.61461353 -0.8463407 ], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.0803169  1.7188319], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.1100413 0.9232185], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.08670617 -0.73792654], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.9416812  1.373748 ], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.33984047 -1.1765858 ], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.4614555 -1.4649161], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.6254022  0.8040849], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.0299916  1.8432682], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.1979443   0.83264965], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.4788664  2.       ], New Position: [0.  5.5], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-0.09875698  0.3798983 ], New Position: [0.  5.5], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-0.5971598   0.13757129], New Position: [0.  5.5], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-0.03287856 -1.7081062 ], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.1316714 -0.7242727], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.2430191  0.78059405], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.5597742  -0.12587489], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.69662064 0.11777546], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7893638  -0.27751872], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.2789167  0.2059199], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.1903299  2.       ], New Position: [0.  5.5], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [1.2054484 0.0472513], New Position: [0.  5.5], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [ 1.2573789 -1.5224906], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.58532816  0.84871846], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.77538913 -0.0926527 ], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.9438061 -1.4015775], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.06553453 -1.1096194 ], New Position: [0.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [2.         0.23780021], New Position: [0.5 5.5], New Velocity: [1 0], Reward: 10, Terminated: False
# Action: [-0.3651318 -0.1271192], New Position: [0.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.03694631 -0.5909448 ], New Position: [0.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.777102   0.22018503], New Position: [0.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.1786151 2.       ], New Position: [0.5 6. ], New Velocity: [0 1], Reward: 10, Terminated: False
# Action: [0.3198716  0.22545266], New Position: [0.5 6.5], New Velocity: [0 1], Reward: -5, Terminated: False
# Action: [-0.94207746 -0.35176498], New Position: [0.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.4666342 1.691488 ], New Position: [0.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.1187429   0.81335664], New Position: [0.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.1644237 -0.3078954], New Position: [0.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.0037897 -1.0692978], New Position: [0.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [2.         0.84684724], New Position: [1.  6.5], New Velocity: [1 0], Reward: 10, Terminated: False
# Action: [-1.5701847   0.13275468], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.6097564 -1.9403242], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.1977499 -1.1914492], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.4765927   0.04730513], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.39744377 -0.952332  ], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.6659598 1.1152878], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# ...
# Action: [0.13415743 1.6581225 ], New Position: [7.  6.5], New Velocity: [1 0], Reward: -100000, Terminated: False
# Action: [0.95595753 2.        ], New Position: [7.  6.5], New Velocity: [1 1], Reward: -100000, Terminated: False
# Action: [2.        1.1536721], New Position: [7.  6.5], New Velocity: [2 1], Reward: -100000, Terminated: False
# Action: [-0.7486191  -0.77297384], New Position: [7.  6.5], New Velocity: [1 0], Reward: -100000, Terminated: False
# Action: [-0.22953929 -0.73504317], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.3350298 -0.4653659], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 2.        -0.4055988], New Position: [7.  6.5], New Velocity: [1 0], Reward: -100000, Terminated: False
# Action: [0.6973984 0.6211407], New Position: [7.  6.5], New Velocity: [1 0], Reward: -100000, Terminated: False
# Action: [-0.28177398 -0.36864763], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.6415193  0.12176374], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.91557026 0.88004667], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.10685256 -0.416098  ], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [2.         0.11826211], New Position: [7.  6.5], New Velocity: [1 0], Reward: -100000, Terminated: False
# Action: [-0.34731382  0.09925936], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.4118321  0.81598234], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7962592  0.823413 ], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.6273384 -0.6511352], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.18241905 -0.16112602], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.8654488  0.4352666], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.28008944 -0.34384307], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.17455585 0.76291573], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.8616292   0.05844821], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.20875654 0.569792  ], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.12345229 -1.7014471 ], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.2012397 -0.9919821], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.29610536 -1.5336125 ], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.5340059  0.18408422], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.9996061 -1.0644428], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.85063505 -0.19253656], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.50948656  1.1507691 ], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.9358358 -2.       ], New Position: [7.  6.5], New Velocity: [ 0 -1], Reward: -100000, Terminated: False
# Action: [ 1.9809276 -1.0494459], New Position: [7.  6.5], New Velocity: [ 0 -1], Reward: -100000, Terminated: False
# Action: [ 0.1667231  -0.24138734], New Position: [7.  6.5], New Velocity: [ 0 -1], Reward: -100000, Terminated: False
# Action: [-0.0203442   0.40775508], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.3794707 -0.279271 ], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.3019923 0.4302085], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.35012025 0.37083057], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.2613795  -0.20646736], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.03258474 0.22344238], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.83764356 0.9807964 ], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.8352451  -0.48659822], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.2386317  0.75729233], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.4570117 1.2329015], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.3112353  0.36598042], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.40240192 -2.        ], New Position: [7.  6.5], New Velocity: [ 0 -1], Reward: -100000, Terminated: False
# Action: [1.2542733 1.0736012], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.18081672 0.82864475], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.3100755 -0.6208479], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.12272812  0.7341415 ], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.0445763 -2.       ], New Position: [7.  6.5], New Velocity: [ 0 -1], Reward: -100000, Terminated: False
# Action: [ 1.3414683 -0.5543404], New Position: [7.  6.5], New Velocity: [ 0 -1], Reward: -100000, Terminated: False
# Action: [ 1.064856  -0.9269589], New Position: [7.  6.5], New Velocity: [ 0 -1], Reward: -100000, Terminated: False
# Action: [-1.0724282 -1.6497619], New Position: [7.  6.5], New Velocity: [ 0 -1], Reward: -100000, Terminated: False
# Action: [0.09336852 0.38528934], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.0117877  -0.06896649], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.83652693 -1.2383044 ], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.16006912 0.7091586 ], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.1672598  -0.51580167], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.91932935 0.75866187], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.0917141  -0.07413964], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.3175858 -1.2518232], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.407593 0.783692], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.19471817 -0.04231797], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.05861094 -0.50156784], New Position: [7.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-2.         -0.04242553], New Position: [6.5 6.5], New Velocity: [-1  0], Reward: 10, Terminated: False
# Action: [ 2.       -1.058358], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.4695087  -0.08236561], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.3316934  1.9444469], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.52657086 -1.1673168 ], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.1645718 0.5881802], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.91982937  2.        ], New Position: [6.5 7. ], New Velocity: [0 1], Reward: -5, Terminated: False
# Action: [-0.6522757   0.23546539], New Position: [6.5 7. ], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-0.38725436 -0.2862445 ], New Position: [6.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.4550978 -1.5960276], New Position: [6.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.7685065 -2.       ], New Position: [6.5 6.5], New Velocity: [ 0 -1], Reward: 10, Terminated: False
# Action: [-0.59063923  0.92455757], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7282102 -0.8930543], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.99691635 -0.6527881 ], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.4922996  -0.63107634], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.11358596 -0.16069297], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.6484709  0.5944549], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.50930333 -0.45076367], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.21686722  0.4571197 ], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.15359446 -0.73876095], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.770646    0.74177384], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.5307908 -0.7378051], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.5823226  0.75088835], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.1092646 -1.1437178], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.2978246  0.53568166], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.1382337  -0.62182444], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.2996001 -0.6828002], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.10337428  1.9464214 ], New Position: [6.5 6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.28198814  2.        ], New Position: [6.5 7. ], New Velocity: [0 1], Reward: -5, Terminated: False
# Action: [1.0543013  0.85139716], New Position: [6.5 7. ], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [ 0.3563533 -0.5927274], New Position: [6.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.45123044 0.62594557], New Position: [6.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.21523373  0.47240403], New Position: [6.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.93100166 1.0610266 ], New Position: [6.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.4971702  -0.01507237], New Position: [6.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.3043206 -1.7294823], New Position: [6.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.5783318  0.8940359], New Position: [6.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.2696246 0.5543667], New Position: [6.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.08383794  1.5713356 ], New Position: [6.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.23845448 -0.0131276 ], New Position: [6.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.865776    0.20489983], New Position: [6.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.99667764  0.28699505], New Position: [6.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.56360406 -1.0938488 ], New Position: [6.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.42385414  0.18467253], New Position: [6.5 7. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.75867844 -2.        ], New Position: [6.5 6.5], New Velocity: [ 0 -1], Reward: 10, Terminated: False
# Action: [-1.6359986  -0.16695377], New Position: [6.5 6. ], New Velocity: [ 0 -1], Reward: 10, Terminated: False
# Action: [0.3525221 2.       ], New Position: [6.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.68851584 0.4259253 ], New Position: [6.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.5832714 0.6165189], New Position: [6.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7646151 -1.5417928], New Position: [6.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.3598466  0.342701 ], New Position: [6.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.92414993 -1.1281534 ], New Position: [6.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.87042856  1.7976464 ], New Position: [6.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.75510764 -1.5755773 ], New Position: [6.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-2.         1.6559381], New Position: [6. 6.], New Velocity: [-1  0], Reward: 10, Terminated: False
# Action: [-1.791143    0.24370706], New Position: [5.5 6. ], New Velocity: [-1  0], Reward: -5, Terminated: False
# Action: [-1.6816808  0.6871397], New Position: [5. 6.], New Velocity: [-1  0], Reward: -5, Terminated: False
# Action: [0.2677783  0.04835023], New Position: [5. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7612858  1.1370332], New Position: [5. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.2490412 1.1825571], New Position: [5. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.0518012 -0.5983239], New Position: [5. 6.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 2.        -0.4849079], New Position: [5.5 6. ], New Velocity: [1 0], Reward: 10, Terminated: False
# Action: [-0.8722018 -1.4699792], New Position: [5.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.95530796 0.35646293], New Position: [5.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.11924896  0.03451421], New Position: [5.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.4242344  0.55443424], New Position: [5.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.1935943   0.12486676], New Position: [5.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.4571975 -0.2597224], New Position: [5.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.45016792 -0.7420862 ], New Position: [5.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.5595323 0.6348313], New Position: [5.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.31158018 -0.81687254], New Position: [5.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.8857218  0.73718756], New Position: [5.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.18063094  0.9666795 ], New Position: [5.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.22234629 -0.9534001 ], New Position: [5.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.25994158 -1.0526243 ], New Position: [5.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.11707     0.21834491], New Position: [5.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.20885326  1.0049939 ], New Position: [5.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.58988065 -0.25801232], New Position: [5.5 6. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [2.        0.2752892], New Position: [6. 6.], New Velocity: [1 0], Reward: 10, Terminated: False
# Action: [-1.0392383  0.2249315], New Position: [6. 6.], New Velocity: [0 0], Reward: 100000, Terminated: True
# Number of steps taken:  3318

# %% [markdown]
# ## **Case 4: Continuous Markov Decision Process with Probabilistic Reward**

# %% [markdown]
# ### **Environment Definition**

# %%
class ContProbEnv(gym.Env):
    def __init__(self, layout, drone_location, target_location, initial_velocity = np.array([0, 0]), completion_reward = 100000, 
                 obstacle_hit_reward = -100000, reduce_dist_reward = 10, increase_dist_reward = -5, stand_still_reward = -1, speed_limit_x = 5,
                 speed_limit_y = 5, acceleration_limit_x = 2, acceleration_limit_y = 2, time_step = 0.5, distance_threshold = 0.1,
                 wind_acceleration_x_bound = (-1, 1), wind_acceleration_y_bound = (-1, 1)):
        
        super(ContProbEnv, self).__init__()  # Ensure compatibility by calling the parent constructor

        self.layout = layout # Layout is made an attribute of the object so that it can be used in the methods
        self.layout_duplicate = layout.copy() # Duplicate layout to prevent overwriting
        self.rows, self.columns = np.shape(layout) # Obtain the number of rows and columns
        self.raster_dict = raster_scan(layout) # Obtain the dictionary with the raster indexation
        self.start = drone_location # Starting position of the drone
        self.target_location = np.array(target_location) # Target/ Delivery location
        self.agent_location = np.array([self.start[0], self.start[1]]) # Initialize the agent location
        # self.step_count = 0 # Initialize the step count (optional)
        self.velocity = initial_velocity # Initialize the velocity of the agent
        self.speed_limit_x = speed_limit_x # Speed limit in the x-direction
        self.speed_limit_y = speed_limit_y # Speed limit in the y-direction
        self.time_step = time_step # Time step for the simulation
        self.distance_threshold = distance_threshold # Distance threshold for the agent to reach the target
        self.wind_acceleration_x_bound = wind_acceleration_x_bound # Wind acceleration bound in the x-direction
        self.wind_acceleration_y_bound = wind_acceleration_y_bound # Wind acceleration bound in the y-direction

        #######################################################################################################################
        
        # Rewards

        self.completion_reward = completion_reward
        self.obstacle_hit_reward = obstacle_hit_reward
        self.reduce_dist_reward = reduce_dist_reward
        self.increase_dist_reward = increase_dist_reward
        self.reduce_dist_reward = reduce_dist_reward
        self.stand_still_reward = stand_still_reward

        #######################################################################################################################

        # Observations are dictionaries with the agent's location. Note that the target's location is fixed.

        """
        
        We prevent the drone from running over obstacles with the reward mechanism.
        
        """

        self.observation_space = spaces.Dict({
            "agent_position": spaces.Box(low=np.array([0, 0]), high=np.array([self.rows, self.columns]), dtype = np.float32),
            "agent_velocity": spaces.Box(low = np.array([-self.speed_limit_x, -self.speed_limit_y]), 
                                   high = np.array([self.speed_limit_x, self.speed_limit_y]), dtype = np.float32)
        })

        #######################################################################################################################

        self.action_space = spaces.Box(low = np.array([-acceleration_limit_x, -acceleration_limit_y]),
                                        high = np.array([acceleration_limit_x, acceleration_limit_y]), dtype = np.float32)

    ###########################################################################################################################    

    def reset(self, seed = None, **kwargs):
    
        super().reset(seed = seed) # Set the seed for reproducibility
        if seed is not None:
            np.random.seed(seed)

        self.agent_location = self.start # Reset agent location
        self.velocity = np.array([0, 0]) # Reset the velocity
        self.layout = self.layout_duplicate.copy() # Reset the layout

        # Return the observation and an empty dictionary as additional info (as required by Gym)
        return {'agent_position': np.array(self.agent_location), 'agent_velocity': np.array(self.velocity)}, {}
    
    ###########################################################################################################################

    def step(self, action):

        position = self.agent_location
        velocity = self.velocity
        acceleration_x, acceleration_y = action
        
        # Update velocity and position
        velocity[0] = velocity[0] + (acceleration_x * self.time_step)
        velocity[1] = velocity[1] + (acceleration_y * self.time_step)
        position_new = position + (velocity * self.time_step)

        # Check if there are obstacles within the distance_threshold from the new position
        
        possible_obstacle_coordinates = {
                                            "right_up": (np.ceil(position_new[0]), np.ceil(position_new[1])),
                                            "right_down": (np.ceil(position_new[0]), np.floor(position_new[1])),
                                            "left_up": (np.floor(position_new[0]), np.ceil(position_new[1])),
                                            "left_down": (np.floor(position_new[0]), np.floor(position_new[1]))
                                        }

        for value in possible_obstacle_coordinates.values():
            if value[0] >= self.rows or value[1] >= self.columns or value[0] < 0 or value[1] < 0:
                reward = self.obstacle_hit_reward
                terminated = False
                truncated = False
                observation = {'agent_position': position, 'agent_velocity': velocity}
                info = {}  # Add any relevant information here (e.g., additional metrics)
                return observation, reward, terminated, truncated, info
            if self.layout[int(value[0]), int(value[1])] == '#':
                coordinate = np.array([value[0], value[1]])
                if np.linalg.norm(position_new - coordinate) < self.distance_threshold:
                    reward = self.obstacle_hit_reward
                    terminated = False
                    truncated = False
                    observation = {'agent_position': position, 'agent_velocity': velocity}
                    info = {}  # Add any relevant information here (e.g., additional metrics)
                    return observation, reward, terminated, truncated, info

        # Update the agent's position and velocity

        self.agent_location = position_new
        self.velocity = velocity
        if np.linalg.norm(self.agent_location - self.target_location) < np.linalg.norm(position - self.target_location):
            reward = self.reduce_dist_reward + np.random.uniform(self.wind_acceleration_x_bound[0], self.wind_acceleration_x_bound[1]) + np.random.uniform(self.wind_acceleration_y_bound[0], self.wind_acceleration_y_bound[1])
            terminated = False
            truncated = False
            observation = {'agent_position': position_new, 'agent_velocity': velocity}
            info = {}
            return observation, reward, terminated, truncated, info
        
        if np.linalg.norm(self.agent_location - self.target_location) > np.linalg.norm(position - self.target_location):
            reward = self.increase_dist_reward + np.random.uniform(self.wind_acceleration_x_bound[0], self.wind_acceleration_x_bound[1]) + np.random.uniform(self.wind_acceleration_y_bound[0], self.wind_acceleration_y_bound[1])
            terminated = False
            truncated = False
            observation = {'agent_position': position_new, 'agent_velocity': velocity}
            info = {}
            return observation, reward, terminated, truncated, info

        # An episode is done if the agent is within the distance threshold from the target

        if np.linalg.norm(self.agent_location - self.target_location) < self.distance_threshold:
            terminated = True
            truncated = False
            reward = self.completion_reward
            observation = {'agent_position': np.array(self.agent_location), 'agent_velocity': self.velocity}
            info = {}  # Add any relevant information here (e.g., additional metrics)
            return observation, reward, terminated, truncated, info
        
        terminated = False
        truncated = False
        reward = self.stand_still_reward
        observation = {'agent_position': np.array(self.agent_location), 'agent_velocity': self.velocity}
        info = {}  # Add any relevant information here (e.g., additional metrics)
        return observation, reward, terminated, truncated, info

    ###########################################################################################################################

    def render(self, mode = 'human'):
        print(self.layout)  # Print the layout with the agent's current position
        print("Velocity of the Agent: ", self.velocity) # Print the velocity of the agent
        print("Position of the Agent: ", self.agent_location) # Print the agent's location
        return

# %% [markdown]
# ### **Training Phase**

# %%
print("Initial Setup")
layout_size = (8, 8)
drone_location = (1, 1)
target_location = (6, 6)
layout_RL_Learning = strictly_solvable(layout_size, drone_location, target_location, obstacle_density = 0.3) # Generate a solvable layout
env = ContProbEnv(layout_RL_Learning, drone_location, target_location) # Load the environment
print(env.layout)

# Instantiate the model with improved hyperparameters
model = PPO('MultiInputPolicy', env, verbose = 1)

model.learn(total_timesteps = 10000, log_interval = 10) # Train the model with more timesteps and log interval for progress
# Out:
# Initial Setup
# Iterations take:  0
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' '#' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' '#' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ### **Testing Phase**

# %%
print("Initial Setup")
print(layout_RL_Learning)

# Test the model here

obs = env.reset()
counter = 0
for _ in range(10000):
    action, _states = model.predict(obs[0])
    observation, reward, terminated, truncated, info = env.step(action)
    print(f"Action: {action}, New Position: {observation['agent_position']}, New Velocity: {observation['agent_velocity']}, Reward: {reward}, Terminated: {terminated}")
    # env.render()
    counter = counter + 1
    if terminated:
        break

print("Number of steps taken: ", counter)
# Out:
# Initial Setup
# [['#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' 'D' ' ' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' '#' ' ' ' ' '#' '#']
#  ['#' ' ' ' ' '#' ' ' ' ' ' ' '#']
#  ['#' ' ' ' ' '#' ' ' '#' ' ' '#']
#  ['#' ' ' '#' ' ' ' ' ' ' ' ' '#']
#  ['#' '#' '#' ' ' ' ' '#' 'T' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#']]
# Action: [ 0.63149816 -1.549459  ], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.0190611 -0.2758514], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.56908673 -0.7445599 ], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.6053652  1.640103 ], New Position: [1. 1.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.07669318  2.        ], New Position: [1.  1.5], New Velocity: [0 1], Reward: 9.3875442949861, Terminated: False
# Action: [-0.3655585 -1.0874821], New Position: [1.  1.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.63557553  1.538104  ], New Position: [1.  1.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.6370414  1.1307609], New Position: [1.  1.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.2348472   0.46277508], New Position: [1.  1.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.43978927 -1.4651734 ], New Position: [1.  1.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.2681636  -0.12435887], New Position: [1.  1.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.98288524 2.        ], New Position: [1. 2.], New Velocity: [0 1], Reward: 9.666132244393168, Terminated: False
# Action: [1.5562623  0.35969546], New Position: [1.  2.5], New Velocity: [0 1], Reward: 10.186499173860659, Terminated: False
# Action: [ 2.       -1.476137], New Position: [1.5 2.5], New Velocity: [1 0], Reward: 9.56817865363444, Terminated: False
# Action: [0.17370279 0.23391077], New Position: [2.  2.5], New Velocity: [1 0], Reward: 9.636516994829332, Terminated: False
# Action: [-0.05339541  0.44859254], New Position: [2.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.46803704 -0.5401256 ], New Position: [2.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.29545152 0.5812353 ], New Position: [2.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [2.        1.0278326], New Position: [2.5 2.5], New Velocity: [1 0], Reward: 10.102017685914943, Terminated: False
# Action: [-1.2142724  0.8243885], New Position: [2.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.25526953 -0.1781067 ], New Position: [2.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.99234647  1.6314307 ], New Position: [2.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.17164856 1.2906953 ], New Position: [2.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.8178618 -1.9367028], New Position: [2.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 2.        -0.2383139], New Position: [3.  2.5], New Velocity: [1 0], Reward: 9.866051280746987, Terminated: False
# Action: [-1.1251053   0.00264235], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.5393906 -0.8041156], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.10699336  0.77738106], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7564752   0.29201353], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.19243228 -1.1664971 ], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.5896059  1.1816145], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.292148  0.2590849], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.23396918 -0.4945623 ], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.17197238  0.11218233], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-2.          0.74781007], New Position: [2.5 2.5], New Velocity: [-1  0], Reward: -5.234867985962346, Terminated: False
# Action: [-0.45879722  0.5576074 ], New Position: [2.  2.5], New Velocity: [-1  0], Reward: -3.6653630920120723, Terminated: False
# Action: [0.01234799 0.09227412], New Position: [2.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.80657744  1.4616745 ], New Position: [2.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.48990622  0.5914638 ], New Position: [2.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.1466048 -2.       ], New Position: [2.  2.5], New Velocity: [ 0 -1], Reward: -100000, Terminated: False
# Action: [-1.1574917   0.38015878], New Position: [2.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.63745683 -0.91381943], New Position: [2.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.22418815 -0.99380153], New Position: [2.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.3722361 1.5375177], New Position: [2.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.5728451  1.6182106], New Position: [2.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.564023   0.8239179], New Position: [2.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.41389295 -0.4052681 ], New Position: [2.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.33109793 -0.0197071 ], New Position: [2.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.2018702  -0.35062155], New Position: [2.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.2566893  0.4103925], New Position: [2.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.62582433  1.9440969 ], New Position: [2.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-2.         -0.64746994], New Position: [1.5 2.5], New Velocity: [-1  0], Reward: -5.500726240238277, Terminated: False
# Action: [-0.5352189  0.4508522], New Position: [1.  2.5], New Velocity: [-1  0], Reward: -4.1400747752623905, Terminated: False
# Action: [-1.9279611  0.6128094], New Position: [0.5 2.5], New Velocity: [-1  0], Reward: -4.9587465755640805, Terminated: False
# Action: [ 0.32522002 -0.50411403], New Position: [0.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.49348524 -0.23943056], New Position: [0.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.316478  1.802116], New Position: [0.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.2563076 -0.917926 ], New Position: [0.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.816537  1.7671977], New Position: [0.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.453411   -0.10993183], New Position: [0.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.359728  -0.2714571], New Position: [0.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.83177984 -0.05916913], New Position: [0.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.7866253 1.4995575], New Position: [0.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 2.         -0.01484421], New Position: [1.  2.5], New Velocity: [1 0], Reward: 10.840639353095343, Terminated: False
# Action: [-0.19821474 -0.29967937], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.0151637  1.5204831], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.9970298   0.88577926], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.9282304  -0.17065156], New Position: [1.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.7820897 2.       ], New Position: [1. 3.], New Velocity: [0 1], Reward: 9.839129452715813, Terminated: False
# Action: [0.3646934 2.       ], New Position: [1. 4.], New Velocity: [0 2], Reward: 8.031374261987072, Terminated: False
# Action: [0.29098153 1.0058956 ], New Position: [1. 5.], New Velocity: [0 2], Reward: 10.482800934963256, Terminated: False
# Action: [-0.15257056  0.08684647], New Position: [1. 6.], New Velocity: [0 2], Reward: 9.927802850900003, Terminated: False
# Action: [-0.3639094  -0.01473669], New Position: [1.  6.5], New Velocity: [0 1], Reward: -3.991334351110999, Terminated: False
# Action: [-0.83924407 -0.67322004], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.12251616 -0.18196563], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.6836566 -1.0791917], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.2114238  0.77062464], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.6904437 1.3295481], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.79200006 -0.17350644], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.01952206  0.34215063], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.1017199   0.60980266], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.76539946 -0.321703  ], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.1978804 1.5694323], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.08480354 -0.47309288], New Position: [1.  6.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.2666632 -2.       ], New Position: [1. 6.], New Velocity: [ 0 -1], Reward: 10.437431881777702, Terminated: False
# Action: [ 0.73877704 -0.26498014], New Position: [1.  5.5], New Velocity: [ 0 -1], Reward: -4.955768121177369, Terminated: False
# Action: [-0.69291395  1.2123023 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.12726007  1.1688273 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.04997604 -1.2144547 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.5711359 -0.7067154], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.06320263  0.1682557 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.1672727 0.375149 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.89042467 -1.5120735 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.26251677 -0.57928854], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.16506746 -1.3184717 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [2.         0.27295417], New Position: [1.5 5.5], New Velocity: [1 0], Reward: 9.244577475824991, Terminated: False
# Action: [0.40706405 0.58617467], New Position: [2.  5.5], New Velocity: [1 0], Reward: 8.955148919185866, Terminated: False
# Action: [-2.        -0.7018727], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.67524344 0.12989928], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.13882965 -0.00082126], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.56473124 2.        ], New Position: [2.  5.5], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-0.8056365   0.64188886], New Position: [2.  5.5], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [ 1.1223555 -0.7935754], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.8071385  -0.19095728], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.51119196  0.6885704 ], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.3707634   0.20404407], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.89151394 -0.6955047 ], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.3222518  0.44122607], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.26859367  2.        ], New Position: [2.  5.5], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-1.8567481 -0.6782108], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.719892   -0.50836563], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.2498163  0.409089 ], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.48409992 -1.1679916 ], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.74120784 -0.9577199 ], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.5775443  0.05950774], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.5964114  1.5207349], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.34515548 -0.54195833], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-2.          0.73170406], New Position: [1.5 5.5], New Velocity: [-1  0], Reward: -5.4346223829699465, Terminated: False
# Action: [-0.7472953  -0.49091733], New Position: [1.  5.5], New Velocity: [-1  0], Reward: -4.3241058951267455, Terminated: False
# Action: [0.9452927  0.26661414], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.0018356 -1.8011518], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.25148657 -1.089976  ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [2.        0.8975242], New Position: [1.5 5.5], New Velocity: [1 0], Reward: 9.66848956806313, Terminated: False
# Action: [0.14575659 1.6050076 ], New Position: [2.  5.5], New Velocity: [1 0], Reward: 10.00483875599724, Terminated: False
# Action: [0.91030484 0.4683093 ], New Position: [2.5 5.5], New Velocity: [1 0], Reward: 10.731647660345581, Terminated: False
# Action: [-0.7845864  1.7117351], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.2678852 -1.5337816], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.5146786  -0.99901307], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.64807373  0.08521996], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.14272662  0.7233969 ], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.15820104 0.23907802], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.10634703  0.53532416], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.6694419  0.5490103], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.61494    0.7535617], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.7915994 -1.2944766], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.00240265 1.1128706 ], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.0550587  -0.36737475], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.9689326  -0.53132755], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.8024203 -1.1504014], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.57959265 -1.0408398 ], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.45355842 0.8173289 ], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.20416594 -0.52760416], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.260224  0.6896174], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.01638699 -0.82172745], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.8330863  -0.50077224], New Position: [2.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-2.         -0.49902895], New Position: [2.  5.5], New Velocity: [-1  0], Reward: -3.53293595431526, Terminated: False
# Action: [-0.09111462 -0.37609798], New Position: [1.5 5.5], New Velocity: [-1  0], Reward: -4.796160524849359, Terminated: False
# Action: [-0.37197205  0.9726784 ], New Position: [1.  5.5], New Velocity: [-1  0], Reward: -5.221567082920666, Terminated: False
# Action: [0.74339944 1.5695478 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.70518947  0.3425038 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.10709525 0.20067407], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.49451545  1.7967947 ], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.79482657 -0.58997196], New Position: [1.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 2.        -1.3606331], New Position: [1.5 5.5], New Velocity: [1 0], Reward: 8.502987212855714, Terminated: False
# Action: [ 0.5200801 -0.3886141], New Position: [2.  5.5], New Velocity: [1 0], Reward: 11.166573267275771, Terminated: False
# Action: [-2.         -0.46606004], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.50549895  1.5605221 ], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.14000016 -0.7594238 ], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.2542887   0.33495894], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.31044996 0.6754788 ], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.8353926 -0.2938439], New Position: [2.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.5387472 -2.       ], New Position: [2. 5.], New Velocity: [ 0 -1], Reward: -5.301156351340954, Terminated: False
# Action: [-1.3837147  2.       ], New Position: [2. 5.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.65335107 0.2855326 ], New Position: [2. 5.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.7096028  0.26282665], New Position: [2. 5.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.4576031  0.43669698], New Position: [2. 5.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.1505991  -0.43687958], New Position: [2. 5.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.89205885 0.193298  ], New Position: [2. 5.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.6609933 0.5860309], New Position: [2. 5.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.6164197  -0.06141607], New Position: [2. 5.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.4224176  0.30188784], New Position: [2. 5.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.35001332  0.8504625 ], New Position: [2. 5.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.58575964 -1.4316368 ], New Position: [2. 5.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.6511039  0.15079755], New Position: [2. 5.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.7363755  -0.15540282], New Position: [2. 5.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.81975174  1.3411112 ], New Position: [2. 5.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.05134477 -0.9794646 ], New Position: [2. 5.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.6106186   0.37991753], New Position: [2. 5.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [2.        0.8690498], New Position: [2.5 5. ], New Velocity: [1 0], Reward: 10.638424501675678, Terminated: False
# Action: [-0.16920833  0.27014065], New Position: [2.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.5832195 0.4073451], New Position: [2.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.90040225 0.49987495], New Position: [2.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.0155187  -0.03540353], New Position: [2.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.48896393  0.37020007], New Position: [2.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.6216755 -2.       ], New Position: [2.5 4.5], New Velocity: [ 0 -1], Reward: -5.064733137833048, Terminated: False
# Action: [1.3884073  0.92343223], New Position: [2.5 4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.897087  2.      ], New Position: [2.5 5. ], New Velocity: [0 1], Reward: 8.685560583499003, Terminated: False
# Action: [ 2.        -0.6507384], New Position: [3. 5.], New Velocity: [1 0], Reward: 11.282874992351605, Terminated: False
# Action: [ 0.78590184 -0.5345437 ], New Position: [3.5 5. ], New Velocity: [1 0], Reward: 9.4388616397958, Terminated: False
# Action: [-0.3706426  -0.66413075], New Position: [3.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.0648309  1.2971897], New Position: [3.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.126478   0.8272261], New Position: [3.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.3201536   0.81720513], New Position: [3.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.44886205 -0.21656784], New Position: [3.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.06917532 -1.591926  ], New Position: [3.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.41214955 -2.        ], New Position: [3.5 4.5], New Velocity: [ 0 -1], Reward: -4.614518194508804, Terminated: False
# Action: [-0.51093394  1.7995062 ], New Position: [3.5 4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 2.        -0.9609155], New Position: [4.  4.5], New Velocity: [1 0], Reward: 9.360763525661106, Terminated: False
# Action: [ 0.45759583 -1.2264403 ], New Position: [4.5 4.5], New Velocity: [1 0], Reward: 10.55450672788334, Terminated: False
# Action: [-1.0962197 -1.2127712], New Position: [4.5 4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.4633029  0.21641174], New Position: [4.5 4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.2027428 1.7789736], New Position: [4.5 4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.20208706 1.5692201 ], New Position: [4.5 4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.1405186 0.0466403], New Position: [4.5 4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.6654211   0.47225237], New Position: [4.5 4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.6566944  -0.77002984], New Position: [4.5 4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.6618444  -0.16985102], New Position: [4.5 4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.6006509  1.2472169], New Position: [4.5 4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.8639565  -0.84841835], New Position: [4.5 4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.7293607 -0.7393617], New Position: [4.5 4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.3171691 -1.7728765], New Position: [4.5 4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.325003 -2.      ], New Position: [4.5 4. ], New Velocity: [ 0 -1], Reward: -4.4825176485782725, Terminated: False
# Action: [0.21363074 1.1977652 ], New Position: [4.5 4. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.70212334 -1.3532946 ], New Position: [4.5 4. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.3363051   0.55533427], New Position: [4.5 4. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.11909782  1.2528849 ], New Position: [4.5 4. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.83382994 -0.03265049], New Position: [4.5 4. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.71202564 -0.91671956], New Position: [4.5 4. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.13797238  0.18852007], New Position: [4.5 4. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.02867274 -0.43581378], New Position: [4.5 4. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-2.          0.08508526], New Position: [4. 4.], New Velocity: [-1  0], Reward: -4.016704161136403, Terminated: False
# Action: [-0.525012   -0.18250538], New Position: [3.5 4. ], New Velocity: [-1  0], Reward: -4.778665206285936, Terminated: False
# Action: [0.6491049 0.1043674], New Position: [3.5 4. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.4651529  -0.42159885], New Position: [3.5 4. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.43795446 1.0297196 ], New Position: [3.5 4. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.0496178 -0.6936974], New Position: [3.5 4. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.4706117 -0.5966345], New Position: [3.5 4. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.4304224  -0.78889346], New Position: [3.5 4. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.7795593 1.7528888], New Position: [3.5 4. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.14210817 -2.        ], New Position: [3.5 3.5], New Velocity: [ 0 -1], Reward: -4.017365857862403, Terminated: False
# Action: [-0.7006726   0.94314927], New Position: [3.5 3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.8232752  -0.85944533], New Position: [3.5 3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.020069    0.74220026], New Position: [3.5 3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.8942449  -0.02666155], New Position: [3.5 3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.9136833  0.6475746], New Position: [3.5 3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.9802848 1.0995932], New Position: [3.5 3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.77030325 -0.6405677 ], New Position: [3.5 3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.4786254 0.1104574], New Position: [3.5 3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.2765403  -0.13371286], New Position: [3.5 3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.1095085 -2.       ], New Position: [3.5 3. ], New Velocity: [ 0 -1], Reward: -5.7567839909521865, Terminated: False
# Action: [-1.0600911  1.058423 ], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.21648046 -1.6923591 ], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.36040255  0.00695481], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [2.        0.1644075], New Position: [3.5 3. ], New Velocity: [1 0], Reward: -100000, Terminated: False
# Action: [-0.06211414 -0.1912944 ], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.5510613  0.65563124], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-2.          0.69633573], New Position: [3.5 3. ], New Velocity: [-1  0], Reward: -100000, Terminated: False
# Action: [0.6662226 0.3229205], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.3379239 1.9309324], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.36403498 -0.21256047], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.5248567  -0.07532706], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.5245244   0.51300395], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.34998053 -1.45875   ], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.22585374 -0.30909944], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.1712669 -1.279077 ], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.3235869 -0.2633548], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.0785496  -0.18727992], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 2.        -1.0347863], New Position: [3.5 3. ], New Velocity: [1 0], Reward: -100000, Terminated: False
# Action: [-1.4094328  -0.20085679], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.05653822  0.8382592 ], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.51870364 -1.05289   ], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.7809846   0.33886656], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.5872252  -0.48237857], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.73436344  0.19701564], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.0660469 -0.6134417], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.47812605  0.5511044 ], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.48056298 -1.0729116 ], New Position: [3.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.2356415 -2.       ], New Position: [3.5 2.5], New Velocity: [ 0 -1], Reward: -6.630199833443468, Terminated: False
# Action: [1.7729341  0.42894936], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.12419845  1.2771882 ], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.4630134  0.33356643], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.17245103 -1.138997  ], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.3255218   0.55385005], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.59414    0.45988762], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.77664554  0.4781063 ], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.7609217 -1.2852713], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.39362204 0.24085683], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.5080619  1.4274689], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.21839103 -1.1883864 ], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.5185214  0.06064168], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.33239302  0.12007038], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.69531584 -0.20902187], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.44202524 0.6102048 ], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.62277925  0.6756708 ], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.02888885 0.45804185], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.07349043 -0.8714249 ], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.48791975  0.85557264], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.15098798  0.75685674], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.1754371  0.19688618], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.3131949 -1.8642712], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.5828604 1.332848 ], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.49461052 0.5461868 ], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.61373585 -1.4093428 ], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.47349748 0.05433401], New Position: [3.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-2.          0.03011048], New Position: [3.  2.5], New Velocity: [-1  0], Reward: -4.64367077715386, Terminated: False
# Action: [ 0.0501826  -0.90063465], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.899025  1.4999928], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.17196898 0.20762299], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.51205295 -0.8078053 ], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.95166653  0.11953139], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.6661236 -0.5719614], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.11548833 1.5220296 ], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.3330406 0.7570157], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.01692865 -1.8948985 ], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.2084861  2.       ], New Position: [3.  2.5], New Velocity: [0 1], Reward: -100000, Terminated: False
# Action: [-1.2549648  -0.46807167], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.0388638  0.6398251], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.43562832 -0.9823627 ], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.3182414  -0.74782753], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.4735918  1.0791757], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.9732483   0.33310175], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.01936372 0.4491591 ], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.39497736 -0.3764319 ], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.77026045 1.7432669 ], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.4137058  -0.14202477], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.2072028 1.3975099], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.38268456  0.5616671 ], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.089071   -0.02262401], New Position: [3.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-2.          0.42728448], New Position: [2.5 2.5], New Velocity: [-1  0], Reward: -3.27076043345755, Terminated: False
# Action: [0.56197995 1.1235272 ], New Position: [2.5 2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 2.        -0.7028942], New Position: [3.  2.5], New Velocity: [1 0], Reward: 11.414343570467063, Terminated: False
# Action: [ 2.         -0.51824427], New Position: [4.  2.5], New Velocity: [2 0], Reward: 9.615715049579805, Terminated: False
# Action: [-0.17956005  0.2146398 ], New Position: [4.5 2.5], New Velocity: [1 0], Reward: 10.563864952340927, Terminated: False
# Action: [ 1.0697787  -0.04020525], New Position: [5.  2.5], New Velocity: [1 0], Reward: 9.984390997268921, Terminated: False
# Action: [-1.4059292 -1.4134607], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.5695394 -0.5184301], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.2929488  -0.42558476], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.2379385  0.93463874], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.1145849 0.5282989], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.75558907 -0.94335455], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.25378984 0.06579088], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.6175998   0.56645477], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7312362   0.93214065], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.9971792 -1.5855222], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.1303104 -0.6478368], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.43598074 0.24901316], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.04843076  0.3690679 ], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.6073801 -0.7125252], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.4226569  -0.04501174], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.8039477  -0.29417038], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.5203862 -0.5697934], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.2298816  0.61950266], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.11415698  0.5010954 ], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.33240205  0.3154719 ], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.47629547 -1.1937281 ], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.95134705 0.19362795], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.0164366 -0.1827479], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.3663168  0.45645636], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.53312635 0.48379704], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.03302875 -0.08539031], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.0988378 -1.1818386], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.9149018 -2.       ], New Position: [5.  2.5], New Velocity: [ 0 -1], Reward: -100000, Terminated: False
# Action: [0.81583345 0.91787314], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.4464232 0.6811839], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.6456985  1.1145703], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.02056491 -0.08127578], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.41520882 -0.29716563], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.46713    0.8826829], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.40153515 -0.45890626], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.41099337 0.58378834], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.86295056  1.1014483 ], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.3017107 1.9147078], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.2510009  -0.06717111], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.03774044 1.2525116 ], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.030467  1.1710517], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.2030768 -0.5939414], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.42832676 1.2285084 ], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.28028712 0.23505451], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.0583843  1.2033145], New Position: [5.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [2.        1.1166667], New Position: [5.5 2.5], New Velocity: [1 0], Reward: 8.465149138621769, Terminated: False
# Action: [ 1.6059647 -0.7084464], New Position: [6.  2.5], New Velocity: [1 0], Reward: 10.652123807635022, Terminated: False
# Action: [0.5748191  0.14719489], New Position: [6.5 2.5], New Velocity: [1 0], Reward: -4.903828830295436, Terminated: False
# Action: [0.07059237 0.6731976 ], New Position: [7.  2.5], New Velocity: [1 0], Reward: -5.8382865798055015, Terminated: False
# Action: [-0.13344993  0.8007805 ], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [2.        0.9711481], New Position: [7.  2.5], New Velocity: [1 0], Reward: -100000, Terminated: False
# Action: [-0.3264114   0.35443977], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.36016282 -0.8466869 ], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.3264859  -0.07992394], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.5640829  0.3965126], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.3576925  0.204577 ], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.2104927  -0.80804485], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.44618717 -0.39924595], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 4.9141236e-06 -8.0079705e-02], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.04167949 0.53172135], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.22455949 -1.3355947 ], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.90762717  0.4263919 ], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.4139413   0.43697426], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.310729   0.45616198], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.8518427   0.33889586], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.3621697 -0.7473806], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.6007629  0.6075015], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.6490753  0.19733621], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.62935174  0.08392134], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.62610936  1.9819293 ], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.09864207 -1.1723359 ], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.8097024  -0.67239106], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.0636574 1.0595717], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.35343397  0.3600083 ], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.7050856  -0.46819052], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.58437586 -1.4510664 ], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.40251735  0.40336627], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.3626483  0.0377965], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.7089899 -1.1383151], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.34805202  0.18150769], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.3690212  0.00423418], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.60083383 0.60131925], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.2357851  -0.16819678], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.6304199  -0.33639395], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.02356166 -0.69593364], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.8750242 -1.0370673], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.2978705  0.62791085], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.7719911 -1.0886865], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.1468459 1.8065495], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 2.        -1.1892633], New Position: [7.  2.5], New Velocity: [1 0], Reward: -100000, Terminated: False
# Action: [0.07589757 1.9938545 ], New Position: [7.  2.5], New Velocity: [1 0], Reward: -100000, Terminated: False
# Action: [ 2.        -0.6297058], New Position: [7.  2.5], New Velocity: [2 0], Reward: -100000, Terminated: False
# Action: [ 1.8083274  -0.36890405], New Position: [7.  2.5], New Velocity: [2 0], Reward: -100000, Terminated: False
# Action: [-2.        -1.3295436], New Position: [7.  2.5], New Velocity: [1 0], Reward: -100000, Terminated: False
# Action: [ 1.297789 -0.248466], New Position: [7.  2.5], New Velocity: [1 0], Reward: -100000, Terminated: False
# Action: [-1.375171    0.70511764], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 2.        -0.5609666], New Position: [7.  2.5], New Velocity: [1 0], Reward: -100000, Terminated: False
# Action: [ 2.        -1.0187473], New Position: [7.  2.5], New Velocity: [2 0], Reward: -100000, Terminated: False
# Action: [-0.9394013  0.369962 ], New Position: [7.  2.5], New Velocity: [1 0], Reward: -100000, Terminated: False
# Action: [0.47545466 1.0775893 ], New Position: [7.  2.5], New Velocity: [1 0], Reward: -100000, Terminated: False
# Action: [-0.2755494  -0.38152882], New Position: [7.  2.5], New Velocity: [0 0], Reward: -1, Terminated: False
# ...
# Action: [-0.8320491   0.35391533], New Position: [4.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.6558412  -0.36225364], New Position: [4.5 3. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.1738042 2.       ], New Position: [4.5 3.5], New Velocity: [0 1], Reward: 10.358324330495126, Terminated: False
# Action: [-1.1147932  -0.69588894], New Position: [4.5 3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7840658  -0.07389738], New Position: [4.5 3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.5375715 -0.8273036], New Position: [4.5 3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.36938736  0.01227408], New Position: [4.5 3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.5193645 1.4760591], New Position: [4.5 3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 2.         -0.17820555], New Position: [5.  3.5], New Velocity: [1 0], Reward: 10.01141535400417, Terminated: False
# Action: [-1.566898    0.40475655], New Position: [5.  3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.27436668  1.485418  ], New Position: [5.  3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.35780612 0.8067652 ], New Position: [5.  3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.24328573  0.5740037 ], New Position: [5.  3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.57263166 -0.42515513], New Position: [5.  3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.24331473 -1.4374226 ], New Position: [5.  3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.0966138  -0.84948015], New Position: [5.  3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.3118147  1.2467018], New Position: [5.  3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.21165  1.261885], New Position: [5.  3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.44785222 -1.1870996 ], New Position: [5.  3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.82832396 -1.6616232 ], New Position: [5.  3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.8573066  -0.05642714], New Position: [5.  3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.21297196 -1.6595883 ], New Position: [5.  3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.94519335 -0.38355896], New Position: [5.  3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.0904652  0.40668112], New Position: [5.  3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.32739246 0.04541198], New Position: [5.  3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.6897582 -1.822183 ], New Position: [5.  3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.53335524 1.1550897 ], New Position: [5.  3.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.6099785 2.       ], New Position: [5. 4.], New Velocity: [0 1], Reward: 11.103381730032005, Terminated: False
# Action: [0.48945862 1.7894509 ], New Position: [5.  4.5], New Velocity: [0 1], Reward: 10.363112888406725, Terminated: False
# Action: [ 0.03075516 -0.23499124], New Position: [5.  4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.70199484 0.24185392], New Position: [5.  4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.3214245  1.4776729], New Position: [5.  4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.4107742 -1.9348065], New Position: [5.  4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.8670796   0.14837343], New Position: [5.  4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.1340915 0.4003686], New Position: [5.  4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.8044907  0.19545418], New Position: [5.  4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.18313178  1.6414798 ], New Position: [5.  4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.6815972  -0.63018644], New Position: [5.  4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.0487695  -0.42078748], New Position: [5.  4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.1480479e-03  2.0000000e+00], New Position: [5. 5.], New Velocity: [0 1], Reward: 10.22206870995638, Terminated: False
# Action: [-0.0633041  0.511805 ], New Position: [5.  5.5], New Velocity: [0 1], Reward: 9.438293216290598, Terminated: False
# Action: [ 0.72018456 -0.7280431 ], New Position: [5.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.97377783  1.6056892 ], New Position: [5.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.4491932  0.3724512], New Position: [5.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.46993122 0.9731385 ], New Position: [5.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.42661783 0.12988925], New Position: [5.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.3735709 -1.9741933], New Position: [5.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.48847166 -1.5880032 ], New Position: [5.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.06382582 0.56153095], New Position: [5.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.7828829 1.9443538], New Position: [5.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.35605752  0.7734782 ], New Position: [5.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.07831746 -0.19081755], New Position: [5.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.6728965 -1.4699906], New Position: [5.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.02164713 -0.13462609], New Position: [5.  5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-2.        -1.1141975], New Position: [4.5 5.5], New Velocity: [-1  0], Reward: -4.534141055044366, Terminated: False
# Action: [0.53965735 0.6060524 ], New Position: [4.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.0255152  -0.26646882], New Position: [4.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.6749396  -0.11510847], New Position: [4.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.4947287 1.0156186], New Position: [4.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.6128265 1.29142  ], New Position: [4.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.12815395 1.5732379 ], New Position: [4.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.1106874 -2.       ], New Position: [4.5 5. ], New Velocity: [ 0 -1], Reward: -5.043150642483701, Terminated: False
# Action: [ 0.7219109 -1.3433493], New Position: [4.5 4.5], New Velocity: [ 0 -1], Reward: -5.10049623863706, Terminated: False
# Action: [1.1274844  0.60492283], New Position: [4.5 4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.0742005  0.8822808], New Position: [4.5 4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.58766574 -0.2503446 ], New Position: [4.5 4.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 2. -2.], New Position: [5. 4.], New Velocity: [ 1 -1], Reward: -6.0443406044557735, Terminated: False
# Action: [-0.8147743   0.28551525], New Position: [5. 4.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.70470476 -0.12359337], New Position: [5. 4.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.5049894 -0.6423919], New Position: [5. 4.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.5126452  0.44642982], New Position: [5. 4.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.5623553 -0.4116724], New Position: [5. 4.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.9195194  0.76236606], New Position: [5. 4.], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [2.       0.588285], New Position: [5.5 4. ], New Velocity: [1 0], Reward: 9.455754397641678, Terminated: False
# Action: [-0.63698256 -0.08380412], New Position: [5.5 4. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.08139428  1.4491258 ], New Position: [5.5 4. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.68491346 2.        ], New Position: [5.5 4.5], New Velocity: [0 1], Reward: 10.11009559837992, Terminated: False
# Action: [0.6298147  0.74689513], New Position: [5.5 5. ], New Velocity: [0 1], Reward: 8.594771670495797, Terminated: False
# Action: [-0.61653215 -0.61545175], New Position: [5.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.3717107   0.13637842], New Position: [5.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.19980375  0.0380384 ], New Position: [5.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7339134 -0.6281443], New Position: [5.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.4290631  1.0865817], New Position: [5.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.5285403 1.519147 ], New Position: [5.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.19130808 -0.20504993], New Position: [5.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.9712518 -0.5398457], New Position: [5.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.02939476 -1.086673  ], New Position: [5.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.2555615  0.24104607], New Position: [5.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.0532193  -0.11723601], New Position: [5.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.1610327 -1.4706546], New Position: [5.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.06401723 -0.748479  ], New Position: [5.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.9105887 -0.7721176], New Position: [5.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.32194623 -1.124243  ], New Position: [5.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.70281136 -0.5378244 ], New Position: [5.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.3377901 -1.1017591], New Position: [5.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.7491568  -0.10029376], New Position: [5.5 5. ], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.8166554 2.       ], New Position: [5.5 5.5], New Velocity: [0 1], Reward: 9.492667265550754, Terminated: False
# Action: [ 0.13464165 -1.1305138 ], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.02385689 -1.8768202 ], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.74379575 -0.98467666], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.3674892  0.15112379], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.37448803  0.10997133], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.5339818  1.4468945], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.612594  0.7440647], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.3290013  -0.15772647], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.5281886 -1.031854 ], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.39084917 -0.05127625], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.7625963  -0.33271804], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.39422482 -0.39277813], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.96661216 -0.59872246], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.07741278 -1.1617854 ], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.0888594 1.6514916], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.27769005 0.4906165 ], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.17716855 -0.38264784], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.21209809 -0.03457549], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.30895844 -1.4714667 ], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.23189332  1.2408711 ], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.2339547 -0.6398877], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-8.7276137e-01 -5.8495719e-04], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.60447377 0.27929837], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.541906  -0.8445364], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.9392965 0.335496 ], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.03825411 0.60441023], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.17364286 0.40772152], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.95973545 0.9002869 ], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [0.12317714 0.22471534], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.7759473 -1.349065 ], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.46152583 -0.29390344], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 0.8547335  -0.10010993], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.48309174 -1.4745616 ], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.3666488  -0.44248438], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.8787057 -1.0517964], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.359969    0.35029793], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [ 1.644312   -0.08519591], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.55615395  1.0672469 ], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.823368  -1.7524534], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-0.27288014 -1.5025638 ], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [-1.7677497  1.4126757], New Position: [5.5 5.5], New Velocity: [0 0], Reward: -1, Terminated: False
# Action: [1.168825 2.      ], New Position: [5.5 6. ], New Velocity: [0 1], Reward: 10.420590285718237, Terminated: False
# Action: [0.87396204 1.4786942 ], New Position: [5.5 6.5], New Velocity: [0 1], Reward: -4.514578017354324, Terminated: False
# Action: [ 2.        -0.5547291], New Position: [6.  6.5], New Velocity: [1 0], Reward: 8.840790078396779, Terminated: False
# Action: [-1.2508665 -2.       ], New Position: [6. 6.], New Velocity: [ 0 -1], Reward: 11.282465914925542, Terminated: False
# Action: [-0.7080552   0.87361676], New Position: [6. 6.], New Velocity: [0 0], Reward: 100000, Terminated: True
# Number of steps taken:  6932

# %% [markdown]
# # **Algorithm Contrast and Comparison**

# %% [markdown]
# ## **Discrete Environment with Deterministic Reward**

# %% [markdown]
# ### **Greedy Algorithm Performance:**

# %%
size = [5, 6, 7, 8] # Size of the layout
obstacle_density = [0, 0.1, 0.2, 0.3, 0.4] # Obstacle density
n_test_cases = 51 # Number of test cases
drone_location = (1, 1) # Example drone location
iterations = np.zeros(len(test_cases) * n_test_cases) # Initialize an array to store the number of steps taken
max_iter = 100 # Maximum number of iterations
average_iterations = np.zeros(len(test_cases)) # Initialize an array to store the average number of steps taken

for i in range(len(test_cases)):
    target_location = (size[i // 5] - 2, size[i // 5] - 2)
    for j in range(n_test_cases):
        env = DiscDetEnv(test_cases[i][j], drone_location, target_location)
        state = env.reset()
        terminated = False
        counter = 0

        while not terminated:
            reward, terminated, action = env.step()
            state = env.agent_location
            counter = counter + 1

            if counter > max_iter:
                break

        iterations[i * n_test_cases + j] = counter

for i in range(len(test_cases)):
    average_iterations[i] = np.mean(iterations[i * n_test_cases: (i + 1) * n_test_cases])

for i in range(len(size)):
    for j in range(len(obstacle_density)):
        print(f"Size: {size[i]}, Obstacle Density: {obstacle_density[j]}, Average Iterations: {average_iterations[i * len(obstacle_density) + j]}")
# Out:
# Size: 5, Obstacle Density: 0, Average Iterations: 4.0
# Size: 5, Obstacle Density: 0.1, Average Iterations: 6.019607843137255
# Size: 5, Obstacle Density: 0.2, Average Iterations: 4.235294117647059
# Size: 5, Obstacle Density: 0.3, Average Iterations: 10.450980392156863
# Size: 5, Obstacle Density: 0.4, Average Iterations: 6.098039215686274
# Size: 6, Obstacle Density: 0, Average Iterations: 6.0
# Size: 6, Obstacle Density: 0.1, Average Iterations: 8.490196078431373
# Size: 6, Obstacle Density: 0.2, Average Iterations: 9.0
# Size: 6, Obstacle Density: 0.3, Average Iterations: 13.27450980392157
# Size: 6, Obstacle Density: 0.4, Average Iterations: 9.156862745098039
# Size: 7, Obstacle Density: 0, Average Iterations: 8.0
# Size: 7, Obstacle Density: 0.1, Average Iterations: 10.450980392156863
# Size: 7, Obstacle Density: 0.2, Average Iterations: 13.294117647058824
# Size: 7, Obstacle Density: 0.3, Average Iterations: 21.294117647058822
# Size: 7, Obstacle Density: 0.4, Average Iterations: 15.764705882352942
# Size: 8, Obstacle Density: 0, Average Iterations: 10.0
# Size: 8, Obstacle Density: 0.1, Average Iterations: 11.529411764705882
# Size: 8, Obstacle Density: 0.2, Average Iterations: 20.84313725490196
# Size: 8, Obstacle Density: 0.3, Average Iterations: 25.529411764705884
# Size: 8, Obstacle Density: 0.4, Average Iterations: 25.980392156862745

# %% [markdown]
# ### **Header Code**

# %%
size = [5, 6, 7, 8] # Size of the layout
obstacle_density = [0, 0.1, 0.2, 0.3, 0.4] # Obstacle density
n_test_cases = 51 # Number of test cases
drone_location = (1, 1) # Example drone location
iterations = np.zeros(len(test_cases) * n_test_cases) # Initialize an array to store the number of steps taken
max_iter = 1000 # Maximum number of iterations
average_iterations = np.zeros(len(test_cases)) # Initialize an array to store the average number of steps taken
counter = 0
base_timesteps = 2500

# %% [markdown]
# ### **DQN Performance**

# %%
for i in range(len(test_cases)):
    target_location = (size[i // 5] - 2, size[i // 5] - 2)
    if (i + 1) % 5 == 0:
        env = DiscDetCompatEnv(test_cases[i][0], drone_location, target_location)

        # Instantiate the model with improved hyperparameters
        model = DQN('MultiInputPolicy', env, 
                    verbose=1,
                    learning_rate = 1e-2,    # Slightly lower learning rate
                    buffer_size = 100000,    # Increase buffer size for more experience replay
                    batch_size = 32,         # Batch size for more stable training
                    learning_starts = 100,  # Start learning after 100 timesteps
                    exploration_fraction = 0.5,  # Keep exploration high initially
                    exploration_final_eps = 0.25,  # Final epsilon after decay
                    gamma = 0.35)  # Discount factor (gamma) for the future reward

        model.learn(total_timesteps = base_timesteps * i, log_interval = 4) # Train the model with more timesteps and log interval for progress

        for j in range(i - 4, i + 1, 1):
            for k in range(n_test_cases):
                env = DiscDetCompatEnv(test_cases[j][k], drone_location, target_location)
                obs = env.reset()
                terminated = False
                counter = 0

                for _ in range(max_iter):
                    action, _states = model.predict(obs[0])
                    observation, reward, terminated, truncated, info = env.step(action)
                    counter = counter + 1
                    if terminated:
                        break

                iterations[j * n_test_cases + k] = counter

for i in range(len(test_cases)):
    average_iterations[i] = np.mean(iterations[i * n_test_cases: (i + 1) * n_test_cases])

for i in range(len(size)):
    for j in range(len(obstacle_density)):
        print(f"Size: {size[i]}, Obstacle Density: {obstacle_density[j]}, Average Iterations: {average_iterations[i * len(obstacle_density) + j]}")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 60.2      |
# |    ep_rew_mean      | -2.92e+06 |
# |    exploration_rate | 0.25      |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 975       |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 241       |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 6.56e+04  |
# |    n_updates        | 35        |
# -----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 52.8      |
# |    ep_rew_mean      | -2.72e+06 |
# |    exploration_rate | 0.548     |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 974       |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 211       |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 7.81e+04  |
# |    n_updates        | 27        |
# -----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Size: 5, Obstacle Density: 0, Average Iterations: 44.372549019607845
# Size: 5, Obstacle Density: 0.1, Average Iterations: 43.372549019607845
# Size: 5, Obstacle Density: 0.2, Average Iterations: 95.0
# Size: 5, Obstacle Density: 0.3, Average Iterations: 102.84313725490196
# Size: 5, Obstacle Density: 0.4, Average Iterations: 75.86274509803921
# Size: 6, Obstacle Density: 0, Average Iterations: 98.52941176470588
# Size: 6, Obstacle Density: 0.1, Average Iterations: 149.2156862745098
# Size: 6, Obstacle Density: 0.2, Average Iterations: 261.84313725490193
# Size: 6, Obstacle Density: 0.3, Average Iterations: 257.7843137254902
# Size: 6, Obstacle Density: 0.4, Average Iterations: 172.47058823529412
# Size: 7, Obstacle Density: 0, Average Iterations: 994.5098039215686
# Size: 7, Obstacle Density: 0.1, Average Iterations: 1000.0
# Size: 7, Obstacle Density: 0.2, Average Iterations: 1000.0
# Size: 7, Obstacle Density: 0.3, Average Iterations: 1000.0
# Size: 7, Obstacle Density: 0.4, Average Iterations: 1000.0
# Size: 8, Obstacle Density: 0, Average Iterations: 219.33333333333334
# Size: 8, Obstacle Density: 0.1, Average Iterations: 364.4901960784314
# Size: 8, Obstacle Density: 0.2, Average Iterations: 557.7647058823529
# Size: 8, Obstacle Density: 0.3, Average Iterations: 460.84313725490193
# Size: 8, Obstacle Density: 0.4, Average Iterations: 510.5098039215686

# %% [markdown]
# ### **PPO Performance**

# %%
for i in range(len(test_cases)):
    target_location = (size[i // 5] - 2, size[i // 5] - 2)
    if (i + 1) % 5 == 0:
        env = DiscDetCompatEnv(test_cases[i][0], drone_location, target_location)

        # Instantiate the model with improved hyperparameters
        model = PPO('MultiInputPolicy', env, verbose=1)

        model.learn(total_timesteps = base_timesteps * i, log_interval = 4) # Train the model with more timesteps and log interval for progress

        for j in range(i - 4, i + 1, 1):
            for k in range(n_test_cases):
                env = DiscDetCompatEnv(test_cases[j][k], drone_location, target_location)
                obs = env.reset()
                terminated = False
                counter = 0

                for _ in range(max_iter):
                    action, _states = model.predict(obs[0])
                    observation, reward, terminated, truncated, info = env.step(action)
                    counter = counter + 1
                    if terminated:
                        break

                iterations[j * n_test_cases + k] = counter

for i in range(len(test_cases)):
    average_iterations[i] = np.mean(iterations[i * n_test_cases: (i + 1) * n_test_cases])

for i in range(len(size)):
    for j in range(len(obstacle_density)):
        print(f"Size: {size[i]}, Obstacle Density: {obstacle_density[j]}, Average Iterations: {average_iterations[i * len(obstacle_density) + j]}")

# %% [markdown]
# ### **A2C Performance**

# %%
for i in range(len(test_cases)):
    target_location = (size[i // 5] - 2, size[i // 5] - 2)
    if (i + 1) % 5 == 0:
        env = DiscDetCompatEnv(test_cases[i][0], drone_location, target_location)

        # Instantiate the model with improved hyperparameters
        model = A2C('MultiInputPolicy', env, verbose=1)

        model.learn(total_timesteps = base_timesteps * i, log_interval = 4) # Train the model with more timesteps and log interval for progress

        for j in range(i - 4, i + 1, 1):
            for k in range(n_test_cases):
                env = DiscDetCompatEnv(test_cases[j][k], drone_location, target_location)
                obs = env.reset()
                terminated = False
                counter = 0

                for _ in range(max_iter):
                    action, _states = model.predict(obs[0])
                    observation, reward, terminated, truncated, info = env.step(action)
                    counter = counter + 1
                    if terminated:
                        break

                iterations[j * n_test_cases + k] = counter

for i in range(len(test_cases)):
    average_iterations[i] = np.mean(iterations[i * n_test_cases: (i + 1) * n_test_cases])

for i in range(len(size)):
    for j in range(len(obstacle_density)):
        print(f"Size: {size[i]}, Obstacle Density: {obstacle_density[j]}, Average Iterations: {average_iterations[i * len(obstacle_density) + j]}")

# %% [markdown]
# ## **Discrete Environment with Probabilistic Reward**

# %% [markdown]
# ### **Header Code**

# %%
size = [5, 6, 7, 8] # Size of the layout
obstacle_density = [0, 0.1, 0.2, 0.3, 0.4] # Obstacle density
n_test_cases = 51 # Number of test cases
drone_location = (1, 1) # Example drone location
iterations = np.zeros(len(test_cases) * n_test_cases) # Initialize an array to store the number of steps taken
max_iter = 1000 # Maximum number of iterations
average_iterations = np.zeros(len(test_cases)) # Initialize an array to store the average number of steps taken
counter = 0
base_timesteps = 2500

# %% [markdown]
# ### **DQN Performance**

# %%
for i in range(len(test_cases)):
    target_location = (size[i // 5] - 2, size[i // 5] - 2)
    if (i + 1) % 5 == 0:
        env = DiscProbEnv(test_cases[i][0], drone_location, target_location)

        # Instantiate the model with improved hyperparameters
        model = DQN('MultiInputPolicy', env, verbose=1)

        model.learn(total_timesteps = base_timesteps * i, log_interval = 4) # Train the model with more timesteps and log interval for progress

        for j in range(i - 4, i + 1, 1):
            for k in range(n_test_cases):
                env = DiscProbEnv(test_cases[j][k], drone_location, target_location)
                obs = env.reset()
                terminated = False
                counter = 0

                for _ in range(max_iter):
                    action, _states = model.predict(obs[0])
                    observation, reward, terminated, truncated, info = env.step(action)
                    counter = counter + 1
                    if terminated:
                        break

                iterations[j * n_test_cases + k] = counter

for i in range(len(test_cases)):
    average_iterations[i] = np.mean(iterations[i * n_test_cases: (i + 1) * n_test_cases])

for i in range(len(size)):
    for j in range(len(obstacle_density)):
        print(f"Size: {size[i]}, Obstacle Density: {obstacle_density[j]}, Average Iterations: {average_iterations[i * len(obstacle_density) + j]}")

# %% [markdown]
# ### **PPO Performance**

# %%
for i in range(len(test_cases)):
    target_location = (size[i // 5] - 2, size[i // 5] - 2)
    if (i + 1) % 5 == 0:
        env = DiscProbEnv(test_cases[i][0], drone_location, target_location)

        # Instantiate the model with improved hyperparameters
        model = PPO('MultiInputPolicy', env, verbose = 1)

        model.learn(total_timesteps = base_timesteps * i, log_interval = 4) # Train the model with more timesteps and log interval for progress

        for j in range(i - 4, i + 1, 1):
            for k in range(n_test_cases):
                env = DiscProbEnv(test_cases[j][k], drone_location, target_location)
                obs = env.reset()
                terminated = False
                counter = 0

                for _ in range(max_iter):
                    action, _states = model.predict(obs[0])
                    observation, reward, terminated, truncated, info = env.step(action)
                    counter = counter + 1
                    if terminated:
                        break

                iterations[j * n_test_cases + k] = counter

for i in range(len(test_cases)):
    average_iterations[i] = np.mean(iterations[i * n_test_cases: (i + 1) * n_test_cases])

for i in range(len(size)):
    for j in range(len(obstacle_density)):
        print(f"Size: {size[i]}, Obstacle Density: {obstacle_density[j]}, Average Iterations: {average_iterations[i * len(obstacle_density) + j]}")

# %% [markdown]
# ### **A2C Performance**

# %%
for i in range(len(test_cases)):
    target_location = (size[i // 5] - 2, size[i // 5] - 2)
    if (i + 1) % 5 == 0:
        env = DiscProbEnv(test_cases[i][0], drone_location, target_location)

        # Instantiate the model with improved hyperparameters
        model = A2C('MultiInputPolicy', env, verbose=1)

        model.learn(total_timesteps = base_timesteps * i, log_interval = 4) # Train the model with more timesteps and log interval for progress

        for j in range(i - 4, i + 1, 1):
            for k in range(n_test_cases):
                env = DiscProbEnv(test_cases[j][k], drone_location, target_location)
                obs = env.reset()
                terminated = False
                counter = 0

                for _ in range(max_iter):
                    action, _states = model.predict(obs[0])
                    observation, reward, terminated, truncated, info = env.step(action)
                    counter = counter + 1
                    if terminated:
                        break

                iterations[j * n_test_cases + k] = counter

for i in range(len(test_cases)):
    average_iterations[i] = np.mean(iterations[i * n_test_cases: (i + 1) * n_test_cases])

for i in range(len(size)):
    for j in range(len(obstacle_density)):
        print(f"Size: {size[i]}, Obstacle Density: {obstacle_density[j]}, Average Iterations: {average_iterations[i * len(obstacle_density) + j]}")

# %% [markdown]
# ## **Continuous Environment with Deterministic Reward**

# %% [markdown]
# ### **Header Code**

# %%
size = [5, 6, 7, 8] # Size of the layout
obstacle_density = [0, 0.1, 0.2, 0.3, 0.4] # Obstacle density
n_test_cases = 51 # Number of test cases
drone_location = (1, 1) # Example drone location
iterations = np.zeros(len(test_cases) * n_test_cases) # Initialize an array to store the number of steps taken
max_iter = 9000 # Maximum number of iterations
average_iterations = np.zeros(len(test_cases)) # Initialize an array to store the average number of steps taken
counter = 0
base_timesteps = 1000

# %% [markdown]
# ### **PPO Performance**

# %%
for i in range(len(test_cases)):
    target_location = (size[i // 5] - 2, size[i // 5] - 2)
    if (i + 1) % 5 == 0:
        env = ContDetEnv(test_cases[i][0], drone_location, target_location)

        # Instantiate the model with improved hyperparameters
        model = PPO('MultiInputPolicy', env, verbose = 0)

        model.learn(total_timesteps = base_timesteps * i, log_interval = 4) # Train the model with more timesteps and log interval for progress

        for j in range(i - 4, i + 1, 1):
            for k in range(n_test_cases):
                env = ContDetEnv(test_cases[j][k], drone_location, target_location)
                obs = env.reset()
                terminated = False
                counter = 0

                for _ in range(max_iter):
                    action, _states = model.predict(obs[0])
                    observation, reward, terminated, truncated, info = env.step(action)
                    counter = counter + 1
                    if terminated:
                        break

                iterations[j * n_test_cases + k] = counter

for i in range(len(test_cases)):
    average_iterations[i] = np.mean(iterations[i * n_test_cases: (i + 1) * n_test_cases])

for i in range(len(size)):
    for j in range(len(obstacle_density)):
        print(f"Size: {size[i]}, Obstacle Density: {obstacle_density[j]}, Average Iterations: {average_iterations[i * len(obstacle_density) + j]}")
# Out:
# Size: 5, Obstacle Density: 0, Average Iterations: 2146.6862745098038
# Size: 5, Obstacle Density: 0.1, Average Iterations: 2059.7450980392155
# Size: 5, Obstacle Density: 0.2, Average Iterations: 2289.5098039215686
# Size: 5, Obstacle Density: 0.3, Average Iterations: 2256.274509803922
# Size: 5, Obstacle Density: 0.4, Average Iterations: 1676.7843137254902
# Size: 6, Obstacle Density: 0, Average Iterations: 3167.7843137254904
# Size: 6, Obstacle Density: 0.1, Average Iterations: 2636.4313725490197
# Size: 6, Obstacle Density: 0.2, Average Iterations: 3529.274509803922
# Size: 6, Obstacle Density: 0.3, Average Iterations: 3117.235294117647
# Size: 6, Obstacle Density: 0.4, Average Iterations: 3542.0
# Size: 7, Obstacle Density: 0, Average Iterations: 3299.8039215686276
# Size: 7, Obstacle Density: 0.1, Average Iterations: 4152.666666666667
# Size: 7, Obstacle Density: 0.2, Average Iterations: 4111.745098039216
# Size: 7, Obstacle Density: 0.3, Average Iterations: 4237.137254901961
# Size: 7, Obstacle Density: 0.4, Average Iterations: 3970.725490196078
# Size: 8, Obstacle Density: 0, Average Iterations: 4187.862745098039
# Size: 8, Obstacle Density: 0.1, Average Iterations: 4665.431372549019
# Size: 8, Obstacle Density: 0.2, Average Iterations: 5189.666666666667
# Size: 8, Obstacle Density: 0.3, Average Iterations: 4318.607843137255
# Size: 8, Obstacle Density: 0.4, Average Iterations: 4594.941176470588

# %% [markdown]
# ### **A2C Performance**

# %%
for i in range(len(test_cases)):
    target_location = (size[i // 5] - 2, size[i // 5] - 2)
    if (i + 1) % 5 == 0:
        env = ContDetEnv(test_cases[i][0], drone_location, target_location)

        # Instantiate the model with improved hyperparameters
        model = A2C('MultiInputPolicy', env, verbose = 0)

        model.learn(total_timesteps = base_timesteps * i, log_interval = 4) # Train the model with more timesteps and log interval for progress

        for j in range(i - 4, i + 1, 1):
            for k in range(n_test_cases):
                env = ContDetEnv(test_cases[j][k], drone_location, target_location)
                obs = env.reset()
                terminated = False
                counter = 0

                for _ in range(max_iter):
                    action, _states = model.predict(obs[0])
                    observation, reward, terminated, truncated, info = env.step(action)
                    counter = counter + 1
                    if terminated:
                        break

                iterations[j * n_test_cases + k] = counter

for i in range(len(test_cases)):
    average_iterations[i] = np.mean(iterations[i * n_test_cases: (i + 1) * n_test_cases])

for i in range(len(size)):
    for j in range(len(obstacle_density)):
        print(f"Size: {size[i]}, Obstacle Density: {obstacle_density[j]}, Average Iterations: {average_iterations[i * len(obstacle_density) + j]}")
# Out:
# Size: 5, Obstacle Density: 0, Average Iterations: 1948.3529411764705
# Size: 5, Obstacle Density: 0.1, Average Iterations: 1740.764705882353
# Size: 5, Obstacle Density: 0.2, Average Iterations: 1641.686274509804
# Size: 5, Obstacle Density: 0.3, Average Iterations: 1556.4705882352941
# Size: 5, Obstacle Density: 0.4, Average Iterations: 1741.4705882352941
# Size: 6, Obstacle Density: 0, Average Iterations: 9000.0
# Size: 6, Obstacle Density: 0.1, Average Iterations: 9000.0
# Size: 6, Obstacle Density: 0.2, Average Iterations: 9000.0
# Size: 6, Obstacle Density: 0.3, Average Iterations: 9000.0
# Size: 6, Obstacle Density: 0.4, Average Iterations: 9000.0
# Size: 7, Obstacle Density: 0, Average Iterations: 9000.0
# Size: 7, Obstacle Density: 0.1, Average Iterations: 9000.0
# Size: 7, Obstacle Density: 0.2, Average Iterations: 9000.0
# Size: 7, Obstacle Density: 0.3, Average Iterations: 9000.0
# Size: 7, Obstacle Density: 0.4, Average Iterations: 9000.0
# Size: 8, Obstacle Density: 0, Average Iterations: 9000.0
# Size: 8, Obstacle Density: 0.1, Average Iterations: 9000.0
# Size: 8, Obstacle Density: 0.2, Average Iterations: 9000.0
# Size: 8, Obstacle Density: 0.3, Average Iterations: 9000.0
# Size: 8, Obstacle Density: 0.4, Average Iterations: 9000.0

# %% [markdown]
# ### **SAC Performance**

# %%
for i in range(len(test_cases)):
    target_location = (size[i // 5] - 2, size[i // 5] - 2)
    if (i + 1) % 5 == 0:
        env = ContDetEnv(test_cases[i][0], drone_location, target_location)

        # Instantiate the model with improved hyperparameters
        model = SAC('MultiInputPolicy', env, verbose = 1)

        model.learn(total_timesteps = base_timesteps * i, log_interval = 4) # Train the model with more timesteps and log interval for progress

        for j in range(i - 4, i + 1, 1):
            for k in range(n_test_cases):
                env = ContDetEnv(test_cases[j][k], drone_location, target_location)
                obs = env.reset()
                terminated = False
                counter = 0

                for _ in range(max_iter):
                    action, _states = model.predict(obs[0])
                    observation, reward, terminated, truncated, info = env.step(action)
                    counter = counter + 1
                    if terminated:
                        break

                iterations[j * n_test_cases + k] = counter

for i in range(len(test_cases)):
    average_iterations[i] = np.mean(iterations[i * n_test_cases: (i + 1) * n_test_cases])

for i in range(len(size)):
    for j in range(len(obstacle_density)):
        print(f"Size: {size[i]}, Obstacle Density: {obstacle_density[j]}, Average Iterations: {average_iterations[i * len(obstacle_density) + j]}")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Size: 5, Obstacle Density: 0, Average Iterations: 9000.0
# Size: 5, Obstacle Density: 0.1, Average Iterations: 9000.0
# Size: 5, Obstacle Density: 0.2, Average Iterations: 9000.0
# Size: 5, Obstacle Density: 0.3, Average Iterations: 9000.0
# Size: 5, Obstacle Density: 0.4, Average Iterations: 9000.0
# Size: 6, Obstacle Density: 0, Average Iterations: 9000.0
# Size: 6, Obstacle Density: 0.1, Average Iterations: 9000.0
# Size: 6, Obstacle Density: 0.2, Average Iterations: 9000.0
# Size: 6, Obstacle Density: 0.3, Average Iterations: 9000.0
# Size: 6, Obstacle Density: 0.4, Average Iterations: 9000.0
# Size: 7, Obstacle Density: 0, Average Iterations: 9000.0
# Size: 7, Obstacle Density: 0.1, Average Iterations: 9000.0
# Size: 7, Obstacle Density: 0.2, Average Iterations: 9000.0
# Size: 7, Obstacle Density: 0.3, Average Iterations: 9000.0
# Size: 7, Obstacle Density: 0.4, Average Iterations: 9000.0
# Size: 8, Obstacle Density: 0, Average Iterations: 9000.0
# Size: 8, Obstacle Density: 0.1, Average Iterations: 9000.0
# Size: 8, Obstacle Density: 0.2, Average Iterations: 9000.0
# Size: 8, Obstacle Density: 0.3, Average Iterations: 9000.0
# Size: 8, Obstacle Density: 0.4, Average Iterations: 9000.0

# %% [markdown]
# ## **Continuous Environment with Probabilistic Reward**

# %% [markdown]
# ### **Header Code**

# %%
size = [5, 6, 7, 8] # Size of the layout
obstacle_density = [0, 0.1, 0.2, 0.3, 0.4] # Obstacle density
n_test_cases = 51 # Number of test cases
drone_location = (1, 1) # Example drone location
iterations = np.zeros(len(test_cases) * n_test_cases) # Initialize an array to store the number of steps taken
max_iter = 9000 # Maximum number of iterations
average_iterations = np.zeros(len(test_cases)) # Initialize an array to store the average number of steps taken
counter = 0
base_timesteps = 1000

# %% [markdown]
# ### **PPO Performance**

# %%
for i in range(len(test_cases)):
    target_location = (size[i // 5] - 2, size[i // 5] - 2)
    if (i + 1) % 5 == 0:
        env = ContProbEnv(test_cases[i][0], drone_location, target_location)

        # Instantiate the model with improved hyperparameters
        model = PPO('MultiInputPolicy', env, verbose=1)

        model.learn(total_timesteps = base_timesteps * i, log_interval = 4) # Train the model with more timesteps and log interval for progress

        for j in range(i - 4, i + 1, 1):
            for k in range(n_test_cases):
                env = ContProbEnv(test_cases[j][k], drone_location, target_location)
                obs = env.reset()
                terminated = False
                counter = 0

                for _ in range(max_iter):
                    action, _states = model.predict(obs[0])
                    observation, reward, terminated, truncated, info = env.step(action)
                    counter = counter + 1
                    if terminated:
                        break

                iterations[j * n_test_cases + k] = counter

for i in range(len(test_cases)):
    average_iterations[i] = np.mean(iterations[i * n_test_cases: (i + 1) * n_test_cases])

for i in range(len(size)):
    for j in range(len(obstacle_density)):
        print(f"Size: {size[i]}, Obstacle Density: {obstacle_density[j]}, Average Iterations: {average_iterations[i * len(obstacle_density) + j]}")

# %% [markdown]
# ### **A2C Performance**

# %%
for i in range(len(test_cases)):
    target_location = (size[i // 5] - 2, size[i // 5] - 2)
    if (i + 1) % 5 == 0:
        env = ContProbEnv(test_cases[i][0], drone_location, target_location)

        # Instantiate the model with improved hyperparameters
        model = A2C('MultiInputPolicy', env, verbose=1)

        model.learn(total_timesteps = base_timesteps * i, log_interval = 4) # Train the model with more timesteps and log interval for progress

        for j in range(i - 4, i + 1, 1):
            for k in range(n_test_cases):
                env = ContProbEnv(test_cases[j][k], drone_location, target_location)
                obs = env.reset()
                terminated = False
                counter = 0

                for _ in range(max_iter):
                    action, _states = model.predict(obs[0])
                    observation, reward, terminated, truncated, info = env.step(action)
                    counter = counter + 1
                    if terminated:
                        break

                iterations[j * n_test_cases + k] = counter

for i in range(len(test_cases)):
    average_iterations[i] = np.mean(iterations[i * n_test_cases: (i + 1) * n_test_cases])

for i in range(len(size)):
    for j in range(len(obstacle_density)):
        print(f"Size: {size[i]}, Obstacle Density: {obstacle_density[j]}, Average Iterations: {average_iterations[i * len(obstacle_density) + j]}")

# %% [markdown]
# ### **SAC Performance**

# %%
for i in range(len(test_cases)):
    target_location = (size[i // 5] - 2, size[i // 5] - 2)
    if (i + 1) % 5 == 0:
        env = ContProbEnv(test_cases[i][0], drone_location, target_location)

        # Instantiate the model with improved hyperparameters
        model = SAC('MultiInputPolicy', env, verbose = 1)

        model.learn(total_timesteps = base_timesteps * i, log_interval = 4) # Train the model with more timesteps and log interval for progress

        for j in range(i - 4, i + 1, 1):
            for k in range(n_test_cases):
                env = ContProbEnv(test_cases[j][k], drone_location, target_location)
                obs = env.reset()
                terminated = False
                counter = 0

                for _ in range(max_iter):
                    action, _states = model.predict(obs[0])
                    observation, reward, terminated, truncated, info = env.step(action)
                    counter = counter + 1
                    if terminated:
                        break

                iterations[j * n_test_cases + k] = counter

for i in range(len(test_cases)):
    average_iterations[i] = np.mean(iterations[i * n_test_cases: (i + 1) * n_test_cases])

for i in range(len(size)):
    for j in range(len(obstacle_density)):
        print(f"Size: {size[i]}, Obstacle Density: {obstacle_density[j]}, Average Iterations: {average_iterations[i * len(obstacle_density) + j]}")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Size: 5, Obstacle Density: 0, Average Iterations: 9000.0
# Size: 5, Obstacle Density: 0.1, Average Iterations: 9000.0
# Size: 5, Obstacle Density: 0.2, Average Iterations: 9000.0
# Size: 5, Obstacle Density: 0.3, Average Iterations: 9000.0
# Size: 5, Obstacle Density: 0.4, Average Iterations: 9000.0
# Size: 6, Obstacle Density: 0, Average Iterations: 9000.0
# Size: 6, Obstacle Density: 0.1, Average Iterations: 9000.0
# Size: 6, Obstacle Density: 0.2, Average Iterations: 9000.0
# Size: 6, Obstacle Density: 0.3, Average Iterations: 9000.0
# Size: 6, Obstacle Density: 0.4, Average Iterations: 9000.0
# Size: 7, Obstacle Density: 0, Average Iterations: 9000.0
# Size: 7, Obstacle Density: 0.1, Average Iterations: 9000.0
# Size: 7, Obstacle Density: 0.2, Average Iterations: 9000.0
# Size: 7, Obstacle Density: 0.3, Average Iterations: 9000.0
# Size: 7, Obstacle Density: 0.4, Average Iterations: 9000.0
# Size: 8, Obstacle Density: 0, Average Iterations: 9000.0
# Size: 8, Obstacle Density: 0.1, Average Iterations: 9000.0
# Size: 8, Obstacle Density: 0.2, Average Iterations: 9000.0
# Size: 8, Obstacle Density: 0.3, Average Iterations: 9000.0
# Size: 8, Obstacle Density: 0.4, Average Iterations: 9000.0
